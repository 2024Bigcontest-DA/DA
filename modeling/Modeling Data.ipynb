# %% [markdown]
# ## 구글 드라이브 마운트

# %%
from google.colab import drive
import os

drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/BigContest')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-22529364f009> in <cell line: 4>()
#       2 import os
#       3
# ----> 4 drive.mount('/content/drive')
#       5 os.chdir('/content/drive/MyDrive/BigContest')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %% [markdown]
# ## 라이브러리

# %%
import dask.dataframe as dd
import time
import pandas as pd
import numpy as np
from tqdm import tqdm
from datetime import datetime

# -------------------------------------------------
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## 데이터 불러오기

# %%
od = dd.read_csv('data/OD_all.csv', assume_missing = True, header = 0)

# %%
od.head()

# %%
od.start_time = od.start_time.str[:2]
od.end_time = od.end_time.str[:2]
od.origin_hdong_cd = od.origin_hdong_cd.astype('str')
od.dest_hdong_cd = od.dest_hdong_cd.astype('str')
od.date = od.date.astype('int')
od.origin_purpose = od.origin_purpose.astype('str')
od.dest_purpose = od.dest_purpose.astype('str')

# %%
od.origin_hdong_cd = od.origin_hdong_cd.astype('str')
od.dest_hdong_cd = od.dest_hdong_cd.astype('str')
od.date = od.date.astype('int')
od.modal = od.modal.astype('str')
od.origin_purpose = od.origin_purpose.astype('str')
od.dest_purpose = od.dest_purpose.astype('str')

# %%
od.head()

# %%
od['origin'] = od.origin_hdong_cd.str[:2]
od.origin = od.origin.astype('string')
od.head()

# %% [markdown]
# ## 방문 데이터

# %%
def get_visit_data(od, origin):
  od = change_types(od)
  filtered_od = od[od.origin_hdong_cd.str[:2] == origin]
  filtered_od = filtered_od[filtered_od.dest_purpose.isin(['3.0', '4.0', '5.0'])]
  filtered_od = filtered_od[filtered_od.modal != '0']
  return filtered_od

# %%
def change_types(od):
  od.modal = od.modal.astype('str')
  od.origin_purpose = od.origin_purpose.astype('str')
  od.dest_purpose = od.dest_purpose.astype('str')
  od.od_cnts = od.od_cnts.astype('int')

  return od

# %% [markdown]
# ### 대전

# %%
od_d = od[od.dest_hdong_cd == '3020055000.0'].compute()

# %%
# 출발지: 서울, 도착지: 대전 축제 지역
od_sd = get_visit_data(od_d, '11')
od_sd.shape
# Out:
# (80, 14)

# %%
# 출발지: 부산역, 도착지: 대전 축제 지역
od_bd = get_visit_data(od_d, '26')
od_bd.shape
# Out:
# (19, 14)

# %%
# 출발지: 대전 전체, 도착지: 대전 축제 지역
od_dd = get_visit_data(od_d, '30')
od_dd.shape
# Out:
# (22716, 14)

# %%
d = pd.concat([od_sd, od_bd, od_dd])
d
# Out:
#        origin_hdong_cd dest_hdong_cd      date start_time end_time  gender  \
# 416540    1117062500.0  3020055000.0  20230902         12       16     1.0
# 418637    1168065500.0  3020055000.0  20230902         10       14     0.0
# 257288    1150062000.0  3020055000.0  20230902         10       14     0.0
# 467630    1171053200.0  3020055000.0  20230902         10       13     0.0
# 516480    1165066000.0  3020055000.0  20230902         17       19     0.0
# ...                ...           ...       ...        ...      ...     ...
# 700621    3017064000.0  3020055000.0  20231015         15       15     1.0
# 701919    3020052700.0  3020055000.0  20231015         15       15     1.0
# 704557    3020060000.0  3020055000.0  20231015         10       10     1.0
# 708038    3017065000.0  3020055000.0  20231015         14       15     1.0
# 709199    3020053000.0  3020055000.0  20231015         16       16     1.0
#
#         age modal origin_purpose dest_purpose  od_dist_avg  od_duration_avg  \
# 416540  0.0   0.0            0.0          5.0     272315.0            285.0
# 418637  0.0   0.0            0.0          5.0     262264.0            233.0
# 257288  0.0   5.0            0.0          5.0     283507.0            214.0
# 467630  1.0   0.0            2.0          4.0     294463.0            172.0
# 516480  0.0   0.0            0.0          5.0     158665.0            156.0
# ...     ...   ...            ...          ...          ...              ...
# 700621  3.0   0.0            4.0          4.0      11082.0             19.0
# 701919  4.0   0.0            0.0          4.0      13946.0             30.0
# 704557  3.0   1.0            5.0          5.0      17542.0             26.0
# 708038  4.0   0.0            3.0          3.0      14900.0             40.0
# 709199  3.0   0.0            3.0          3.0      10373.0             15.0
#
#         od_cnts origin
# 416540       21     11
# 418637       27     11
# 257288       27     11
# 467630        9     11
# 516480       27     11
# ...         ...    ...
# 700621        5     30
# 701919        5     30
# 704557        5     30
# 708038        5     30
# 709199        5     30
#
# [22815 rows x 14 columns]

# %% [markdown]
# ### 부산

# %%
od_b = od[od.dest_hdong_cd == '2635052000.0'].compute()

# %%
# 출발지: 서울, 도착지: 부산 축제 지역
od_sb = get_visit_data(od_b, '11')
od_sb.shape
# Out:
# (10, 13)

# %%
# 출발지: 부산, 도착지: 부산 축제 지역
od_bb = get_visit_data(od_b, '26')
od_bb.shape
# Out:
# (11978, 13)

# %%
b = pd.concat([od_sb, od_bb])
b
# Out:
#        origin_hdong_cd dest_hdong_cd      date start_time end_time  gender  \
# 544556    1150062000.0  2635052000.0  20230908         19       22     0.0
# 677801    1150062000.0  2635052000.0  20230910         10       13     1.0
# 171622    1150062000.0  2635052000.0  20230929         19       21     0.0
# 61462     1150062000.0  2635052000.0  20231004         15       18     0.0
# 563449    1150062000.0  2635052000.0  20231005         09       12     0.0
# ...                ...           ...       ...        ...      ...     ...
# 659831    2635051000.0  2635052000.0  20231015         12       13     1.0
# 667263    2671025000.0  2635052000.0  20231015         15       16     1.0
# 670299    2650076000.0  2635052000.0  20231015         17       17     1.0
# 689070    2635053000.0  2635052000.0  20231015         16       16     0.0
# 710594    2635051000.0  2635052000.0  20231015         10       11     1.0
#
#         age modal origin_purpose dest_purpose  od_dist_avg  od_duration_avg  \
# 544556  3.0     7            4.0          5.0     801753.0            165.0
# 677801  3.0     7            5.0          5.0     775150.0            201.0
# 171622  3.0     7            4.0          5.0     738005.0            155.0
# 61462   2.0     7            4.0          5.0     709303.0            196.0
# 563449  3.0     7            4.0          5.0     624110.0            202.0
# ...     ...   ...            ...          ...          ...              ...
# 659831  3.0     2            5.0          5.0      86961.0             67.0
# 667263  2.0     1            4.0          3.0      41651.0             55.0
# 670299  2.0     1            0.0          3.0      11408.0             17.0
# 689070  3.0     2            0.0          3.0      11429.0             26.0
# 710594  2.0     2            5.0          5.0      22304.0             21.0
#
#         od_cnts
# 544556        6
# 677801        6
# 171622        6
# 61462         6
# 563449        6
# ...         ...
# 659831        6
# 667263        5
# 670299        5
# 689070        6
# 710594        5
#
# [11988 rows x 13 columns]

# %% [markdown]
# ### 임실

# %%
od_i = od[od.dest_hdong_cd == '4575034000.0'].compute()

# %%
# 출발지: 서울, 도착지: 임실 축제 지역
od_si = get_visit_data(od_i, '11')
od_si.shape
# Out:
# (16, 13)

# %%
# 출발지: 부산, 도착지: 임실 축제 지역
od_bi = get_visit_data(od_i, '26')
od_bi.shape
# Out:
# (6, 13)

# %%
# 출발지: 임실, 도착지: 임실 축제 지역
od_ii = get_visit_data(od_i, '45')
od_ii.shape
# Out:
# (4002, 13)

# %%
i = pd.concat([od_si, od_bi, od_ii])
i
# Out:
#        origin_hdong_cd dest_hdong_cd      date start_time end_time  gender  \
# 55522     1114065000.0  4575034000.0  20230901      17:00    23:00     0.0
# 501264    1123056000.0  4575034000.0  20230918      09:00    15:00     0.0
# 115509    1168064000.0  4575034000.0  20231001      13:00    18:00     0.0
# 288839    1168065500.0  4575034000.0  20231001      14:00    18:00     0.0
# 534714    1165065100.0  4575034000.0  20231003      09:00    14:00     0.0
# ...                ...           ...       ...        ...      ...     ...
# 579197    4511358000.0  4575034000.0  20231015      11:00    12:00     0.0
# 615468    4511354000.0  4575034000.0  20231015      09:00    11:00     0.0
# 629618    4511173000.0  4575034000.0  20231015      10:00    11:00     0.0
# 640075    4511173000.0  4575034000.0  20231015      08:00    09:00     0.0
# 714641    4511170300.0  4575034000.0  20231015      13:00    15:00     0.0
#
#         age modal origin_purpose dest_purpose  od_dist_avg  od_duration_avg  \
# 55522   3.0   0.0            4.0          5.0     824091.0            361.0
# 501264  3.0   0.0            4.0          5.0     521635.0            367.0
# 115509  3.0   0.0            5.0          5.0     662898.0            282.0
# 288839  3.0   0.0            4.0          5.0     646915.0            239.0
# 534714  3.0   0.0            0.0          5.0     636641.0            325.0
# ...     ...   ...            ...          ...          ...              ...
# 579197  3.0   0.0            4.0          4.0      53509.0             60.0
# 615468  3.0   0.0            5.0          5.0     108036.0            111.0
# 629618  3.0   0.0            0.0          4.0     114664.0            112.0
# 640075  3.0   0.0            5.0          5.0      61838.0             41.0
# 714641  3.0   0.0            0.0          4.0     208055.0             91.0
#
#         od_cnts
# 55522         5
# 501264        5
# 115509        5
# 288839        5
# 534714        5
# ...         ...
# 579197        5
# 615468        5
# 629618        5
# 640075        5
# 714641        5
#
# [4024 rows x 13 columns]

# %% [markdown]
# ### 서울

# %%
od_s = od[od.dest_hdong_cd == '1156054000.0'].compute()

# %%
# 출발지: 서울, 도착지: 서울 축제 지역
od_ss = get_visit_data(od_s, '11')
od_ss.shape
# Out:
# (39621, 13)

# %%
# 출발지: 부산, 도착지: 서울 축제 지역
od_bs = get_visit_data(od_s, '26')
od_bs.shape
# Out:
# (6, 13)

# %%
s = pd.concat([od_ss, od_bs])
s
# Out:
#        origin_hdong_cd dest_hdong_cd      date start_time end_time  gender  \
# 1324      1114055000.0  1156054000.0  20230901      16:00    17:00     1.0
# 4181      1150061100.0  1156054000.0  20230901      12:00    13:00     1.0
# 4648      1154551000.0  1156054000.0  20230901      17:00    18:00     0.0
# 5032      1156051500.0  1156054000.0  20230901      13:00    13:00     1.0
# 6486      1156053500.0  1156054000.0  20230901      18:00    18:00     0.0
# ...                ...           ...       ...        ...      ...     ...
# 43552     2671025000.0  1156054000.0  20230918      11:00    19:00     1.0
# 319417    2644051000.0  1156054000.0  20230920      10:00    18:00     0.0
# 125661    2644051000.0  1156054000.0  20230920      12:00    19:00     0.0
# 72524     2620065000.0  1156054000.0  20230923      12:00    17:00     1.0
# 520691    2644053000.0  1156054000.0  20231014      10:00    13:00     1.0
#
#         age modal origin_purpose dest_purpose  od_dist_avg  od_duration_avg  \
# 1324    3.0   2.0            1.0          3.0      28195.0             41.0
# 4181    0.0   0.0            5.0          5.0      66357.0             52.0
# 4648    3.0   0.0            1.0          3.0      50964.0             42.0
# 5032    2.0   1.0            0.0          3.0      12739.0             19.0
# 6486    3.0   0.0            4.0          4.0      17311.0             21.0
# ...     ...   ...            ...          ...          ...              ...
# 43552   0.0   0.0            5.0          4.0     522036.0            445.0
# 319417  2.0   0.0            4.0          3.0     962175.0            470.0
# 125661  3.0   0.0            4.0          4.0     916380.0            443.0
# 72524   0.0   0.0            0.0          3.0     663418.0            257.0
# 520691  0.0   0.0            0.0          5.0     592146.0            143.0
#
#         od_cnts
# 1324          7
# 4181         19
# 4648          7
# 5032          7
# 6486          7
# ...         ...
# 43552        19
# 319417        5
# 125661        5
# 72524        19
# 520691       19
#
# [39627 rows x 13 columns]

# %% [markdown]
# ### 강릉(1)

# %%
od_ga = od[od.dest_hdong_cd == '5115057200.0'].compute()

# %%
# 출발지: 서울, 도착지: 강릉 스피드 스케이팅 경기장
od_sga = get_visit_data(od_ga, '11')
od_sga.shape
# Out:
# (673, 13)

# %%
# 출발지: 부산, 도착지: 강릉 스피드 스케이팅 경기장
od_bga = get_visit_data(od_ga, '26')
od_bga.shape
# Out:
# (5, 13)

# %%
# 출발지: 강릉, 도착지: 강릉 스피드 스케이팅 경기장
od_gga = get_visit_data(od_ga, '51')
od_gga.shape
# Out:
# (39919, 13)

# %%
ga = pd.concat([od_bga, od_sga, od_gga])
ga
# Out:
#        origin_hdong_cd dest_hdong_cd      date start_time end_time  gender  \
# 118062    2671025600.0  5115057200.0  20230921      16:00    21:00     1.0
# 379158    2671025600.0  5115057200.0  20230921      16:00    21:00     0.0
# 378192    2623067000.0  5115057200.0  20230928      11:00    19:00     1.0
# 646900    2626076100.0  5115057200.0  20230929      08:00    14:00     0.0
# 274051    2638056200.0  5115057200.0  20231007      13:00    18:00     1.0
# ...                ...           ...       ...        ...      ...     ...
# 711120    5115052000.0  5115057200.0  20231015      12:00    13:00     1.0
# 713687    5115057100.0  5115057200.0  20231015      20:00    20:00     0.0
# 713795    5115056000.0  5115057200.0  20231015      17:00    17:00     1.0
# 714799    5115066500.0  5115057200.0  20231015      13:00    15:00     1.0
# 715025    5115025000.0  5115057200.0  20231015      12:00    13:00     1.0
#
#         age modal origin_purpose dest_purpose  od_dist_avg  od_duration_avg  \
# 118062  4.0   0.0            0.0          5.0     816508.0            321.0
# 379158  1.0   0.0            0.0          5.0     490979.0            316.0
# 378192  4.0   0.0            0.0          5.0     761377.0            468.0
# 646900  0.0   0.0            0.0          5.0     659219.0            357.0
# 274051  3.0   0.0            4.0          5.0     886946.0            306.0
# ...     ...   ...            ...          ...          ...              ...
# 711120  4.0   0.0            3.0          3.0      40098.0             14.0
# 713687  2.0   0.0            3.0          3.0       7792.0             16.0
# 713795  3.0   1.0            0.0          3.0      14336.0              9.0
# 714799  1.0   0.0            3.0          5.0     320011.0            101.0
# 715025  3.0   0.0            0.0          3.0      40345.0             29.0
#
#         od_cnts
# 118062        5
# 379158        6
# 378192        5
# 646900       35
# 274051        5
# ...         ...
# 711120        5
# 713687        5
# 713795        5
# 714799        6
# 715025        5
#
# [40597 rows x 13 columns]

# %% [markdown]
# ### 강릉(2)

# %%
od_gb = od[od.dest_hdong_cd == '5115058000.0'].compute()

# %%
# 출발지: 서울, 도착지: 강릉 경포호수광장
od_sgb = get_visit_data(od_gb, '11')
od_sgb.shape
# Out:
# (261, 13)

# %%
# 출발지: 부산, 도착지: 강릉 경포호수광장
od_bgb = get_visit_data(od_gb, '26')
od_bgb.shape
# Out:
# (5, 13)

# %%
# 출발지: 강릉, 도착지: 강릉 경포호수광장
od_ggb = get_visit_data(od_gb, '51')
od_ggb.shape
# Out:
# (23446, 13)

# %%
gb = pd.concat([od_sgb, od_bgb, od_ggb])
gb
# Out:
#        origin_hdong_cd dest_hdong_cd      date start_time end_time  gender  \
# 29620     1165058100.0  5115058000.0  20230901      17:00    21:00     1.0
# 86698     1174054000.0  5115058000.0  20230901      11:00    14:00     0.0
# 36586     1135071000.0  5115058000.0  20230901      10:00    17:00     0.0
# 174691    1135062100.0  5115058000.0  20230901      15:00    18:00     0.0
# 534441    1168059000.0  5115058000.0  20230901      10:00    15:00     0.0
# ...                ...           ...       ...        ...      ...     ...
# 630175    5176034000.0  5115058000.0  20231015      12:00    14:00     0.0
# 635330    5115064500.0  5115058000.0  20231015      11:00    12:00     0.0
# 640355    5176038000.0  5115058000.0  20231015      13:00    14:00     0.0
# 663406    5115051000.0  5115058000.0  20231015      11:00    11:00     0.0
# 678346    5115066500.0  5115058000.0  20231015      18:00    18:00     0.0
#
#         age modal origin_purpose dest_purpose  od_dist_avg  od_duration_avg  \
# 29620   3.0   0.0            4.0          5.0     567221.0            242.0
# 86698   1.0   0.0            0.0          5.0     356188.0            182.0
# 36586   1.0   0.0            4.0          5.0     205557.0            412.0
# 174691  1.0   0.0            0.0          5.0     244374.0            173.0
# 534441  4.0   0.0            4.0          5.0     530850.0            318.0
# ...     ...   ...            ...          ...          ...              ...
# 630175  4.0   0.0            5.0          5.0     227797.0             94.0
# 635330  5.0   0.0            0.0          4.0      14623.0             22.0
# 640355  3.0   0.0            5.0          5.0      92098.0             45.0
# 663406  3.0   0.0            5.0          5.0      29664.0             19.0
# 678346  3.0   0.0            5.0          5.0       7594.0              5.0
#
#         od_cnts
# 29620         7
# 86698         7
# 36586         7
# 174691        7
# 534441        6
# ...         ...
# 630175        6
# 635330        5
# 640355        5
# 663406        5
# 678346        5
#
# [23712 rows x 13 columns]

# %% [markdown]
# ### concat

# %%
od_dd.head()
# Out:
#        origin_hdong_cd dest_hdong_cd      date  start_time  end_time  gender  \
# 98311       3020054000    3020055000  20230901          11        11       0
# 99728       3017055500    3020055000  20230901           9        10       0
# 99999       3020060000    3020055000  20230901           9         9       1
# 122004      3017064000    3020055000  20230901          11        11       1
# 129692      3020054000    3020055000  20230901          11        11       0
#
#         age modal origin_purpose dest_purpose  od_dist_avg  od_duration_avg  \
# 98311     5     1              1            3       8539.0             15.0
# 99728     0     4              0            3       3878.0             40.0
# 99999     3     1              0            4      11536.0             21.0
# 122004    0     1              0            3       4817.0             13.0
# 129692    3     1              1            3       6842.0              8.0
#
#         od_cnts origin
# 98311        12     30
# 99728        27     30
# 99999         8     30
# 122004       21     30
# 129692       19     30

# %%
visit = pd.concat([d, b, i, s, ga, gb])
visit
# Out:
#        origin_hdong_cd dest_hdong_cd      date start_time end_time  gender  \
# 416540    1117062500.0  3020055000.0  20230902         12       16     1.0
# 418637    1168065500.0  3020055000.0  20230902         10       14     0.0
# 257288    1150062000.0  3020055000.0  20230902         10       14     0.0
# 467630    1171053200.0  3020055000.0  20230902         10       13     0.0
# 516480    1165066000.0  3020055000.0  20230902         17       19     0.0
# ...                ...           ...       ...        ...      ...     ...
# 630175    5176034000.0  5115058000.0  20231015      12:00    14:00     0.0
# 635330    5115064500.0  5115058000.0  20231015      11:00    12:00     0.0
# 640355    5176038000.0  5115058000.0  20231015      13:00    14:00     0.0
# 663406    5115051000.0  5115058000.0  20231015      11:00    11:00     0.0
# 678346    5115066500.0  5115058000.0  20231015      18:00    18:00     0.0
#
#         age modal origin_purpose dest_purpose  od_dist_avg  od_duration_avg  \
# 416540  0.0   0.0            0.0          5.0     272315.0            285.0
# 418637  0.0   0.0            0.0          5.0     262264.0            233.0
# 257288  0.0   5.0            0.0          5.0     283507.0            214.0
# 467630  1.0   0.0            2.0          4.0     294463.0            172.0
# 516480  0.0   0.0            0.0          5.0     158665.0            156.0
# ...     ...   ...            ...          ...          ...              ...
# 630175  4.0   0.0            5.0          5.0     227797.0             94.0
# 635330  5.0   0.0            0.0          4.0      14623.0             22.0
# 640355  3.0   0.0            5.0          5.0      92098.0             45.0
# 663406  3.0   0.0            5.0          5.0      29664.0             19.0
# 678346  3.0   0.0            5.0          5.0       7594.0              5.0
#
#         od_cnts origin
# 416540       21     11
# 418637       27     11
# 257288       27     11
# 467630        9     11
# 516480       27     11
# ...         ...    ...
# 630175        6   <NA>
# 635330        5   <NA>
# 640355        5   <NA>
# 663406        5   <NA>
# 678346        5   <NA>
#
# [142763 rows x 14 columns]

# %%
visit.to_csv('data/visit.csv')

# %% [markdown]
# ## 귀가 데이터

# %%
def get_home_data(od, origin):
  od = change_types(od)
  filtered_od = od[od.origin_hdong_cd == origin].compute()
  filtered_od = filtered_od[filtered_od.origin_purpose.isin(['3.0', '4.0', '5.0'])]
  filtered_od = filtered_od[filtered_od.modal != '0']
  return filtered_od

# %%
def change_types(od):
  od.modal = od.modal.astype('str')
  od.origin_purpose = od.origin_purpose.astype('str')
  od.dest_purpose = od.dest_purpose.astype('str')
  od.od_cnts = od.od_cnts.astype('int')

  return od

# %% [markdown]
# ### 대전

# %%
home_d = get_home_data(od, '3020055000.0')
home_d
# Out:
#        origin_hdong_cd dest_hdong_cd      date start_time end_time  gender  \
# 107       3020055000.0  4372039000.0  20230901      08:00    09:00     0.0
# 1416      3020055000.0  3023052500.0  20230901      08:00    09:00     0.0
# 2336      3020055000.0  3017058800.0  20230901      21:00    21:00     1.0
# 2484      3020055000.0  3020054000.0  20230901      17:00    18:00     0.0
# 11393     3020055000.0  3020054000.0  20230901      09:00    10:00     1.0
# ...                ...           ...       ...        ...      ...     ...
# 703813    3020055000.0  3017058800.0  20231015      16:00    17:00     0.0
# 705053    3020055000.0  3017053500.0  20231015      16:00    17:00     1.0
# 706148    3020055000.0  3017064000.0  20231015      17:00    18:00     0.0
# 712563    3020055000.0  3014057500.0  20231015      19:00    19:00     0.0
# 713114    3020055000.0  3020054000.0  20231015      13:00    14:00     1.0
#
#         age modal origin_purpose dest_purpose  od_dist_avg  od_duration_avg  \
# 107     3.0   0.0            4.0          4.0     153144.0             56.0
# 1416    5.0   0.0            4.0          4.0      14091.0             31.0
# 2336    2.0   0.0            3.0          0.0      10497.0             27.0
# 2484    2.0   0.0            3.0          4.0      35412.0             49.0
# 11393   1.0   0.0            5.0          5.0      15195.0             60.0
# ...     ...   ...            ...          ...          ...              ...
# 703813  4.0   0.0            4.0          0.0      17826.0             40.0
# 705053  3.0   1.0            5.0          5.0       9719.0             38.0
# 706148  1.0   0.0            4.0          3.0      23573.0             48.0
# 712563  3.0   0.0            3.0          0.0      15228.0             22.0
# 713114  1.0   0.0            4.0          0.0      12179.0             28.0
#
#         od_cnts
# 107           7
# 1416          8
# 2336          7
# 2484          7
# 11393        22
# ...         ...
# 703813        5
# 705053        5
# 706148        5
# 712563        6
# 713114        5
#
# [93299 rows x 13 columns]

# %% [markdown]
# ### 부산

# %%
home_b = get_home_data(od, '2635052000.0')
home_b
# Out:
#        origin_hdong_cd dest_hdong_cd      date start_time end_time  gender  \
# 1990      2635052000.0  4831039000.0  20230901      19:00    22:00     1.0
# 4573      2635052000.0  2620064000.0  20230901      14:00    15:00     0.0
# 5444      2635052000.0  2635051000.0  20230901      11:00    11:00     1.0
# 5881      2635052000.0  2635051000.0  20230901      19:00    19:00     1.0
# 11167     2635052000.0  2626052000.0  20230901      19:00    20:00     1.0
# ...                ...           ...       ...        ...      ...     ...
# 713609    2635052000.0  2629064500.0  20231015      18:00    19:00     1.0
# 713624    2635052000.0  2647072000.0  20231015      19:00    19:00     1.0
# 713848    2635052000.0  2635051000.0  20231015      14:00    15:00     0.0
# 714024    2635052000.0  2635051000.0  20231015      09:00    09:00     1.0
# 714488    2635052000.0  2635051000.0  20231015      13:00    13:00     0.0
#
#         age modal origin_purpose dest_purpose  od_dist_avg  od_duration_avg  \
# 1990    3.0   0.0            4.0          5.0     319689.0            170.0
# 4573    4.0   0.0            4.0          4.0     108069.0             49.0
# 5444    1.0   0.0            5.0          5.0      38530.0             27.0
# 5881    1.0   0.0            4.0          3.0      22282.0             14.0
# 11167   3.0   0.0            3.0          3.0      50249.0             54.0
# ...     ...   ...            ...          ...          ...              ...
# 713609  5.0   0.0            4.0          0.0      25823.0             23.0
# 713624  2.0   0.0            3.0          4.0      30006.0             44.0
# 713848  3.0   3.0            4.0          4.0      27033.0             62.0
# 714024  2.0   0.0            4.0          0.0      12756.0             17.0
# 714488  3.0   0.0            4.0          4.0       6656.0              9.0
#
#         od_cnts
# 1990          7
# 4573          8
# 5444         14
# 5881          7
# 11167         7
# ...         ...
# 713609        6
# 713624        5
# 713848        5
# 714024        5
# 714488        5
#
# [169893 rows x 13 columns]

# %% [markdown]
# ### 임실

# %%
home_i = get_home_data(od, '4575034000.0')
home_i
# Out:
#        origin_hdong_cd dest_hdong_cd      date start_time end_time  gender  \
# 425467    4575034000.0  4575035500.0  20230901      14:00    14:00     0.0
# 688918    4575034000.0  4617032000.0  20230901      13:00    15:00     0.0
# 296995    4575034000.0  4574031000.0  20230901      17:00    17:00     0.0
# 388078    4575034000.0  4575032000.0  20230901      12:00    14:00     0.0
# 401602    4575034000.0  4511359000.0  20230901      11:00    12:00     1.0
# ...                ...           ...       ...        ...      ...     ...
# 649349    4575034000.0  4373025000.0  20231015      15:00    18:00     1.0
# 675750    4575034000.0  4511354000.0  20231015      17:00    17:00     0.0
# 687251    4575034000.0  4577034000.0  20231015      15:00    16:00     1.0
# 689935    4575034000.0  4575032000.0  20231015      12:00    12:00     1.0
# 707817    4575034000.0  4575032000.0  20231015      15:00    16:00     1.0
#
#         age modal origin_purpose dest_purpose  od_dist_avg  od_duration_avg  \
# 425467  3.0   4.0            4.0          4.0        355.0              1.0
# 688918  3.0   0.0            4.0          4.0     216279.0            141.0
# 296995  3.0   0.0            5.0          5.0      32615.0             15.0
# 388078  4.0   1.0            5.0          3.0      55430.0            118.0
# 401602  1.0   0.0            4.0          0.0      33562.0             44.0
# ...     ...   ...            ...          ...          ...              ...
# 649349  3.0   0.0            5.0          0.0     177750.0            127.0
# 675750  3.0   0.0            4.0          0.0      53267.0             40.0
# 687251  2.0   0.0            5.0          5.0      71232.0             30.0
# 689935  4.0   0.0            4.0          4.0      85154.0             45.0
# 707817  4.0   0.0            4.0          4.0     104175.0            106.0
#
#         od_cnts
# 425467        5
# 688918        5
# 296995        7
# 388078        6
# 401602        6
# ...         ...
# 649349        5
# 675750        5
# 687251        5
# 689935        6
# 707817        6
#
# [4963 rows x 13 columns]

# %%
b = pd.concat([home_d, home_b, home_i]).to_csv('data/temp.csv')

# %% [markdown]
# ### 서울

# %%
home_s = get_home_data(od, '1156054000.0')
home_s
# Out:
#        origin_hdong_cd dest_hdong_cd      date start_time end_time  gender  \
# 330       1156054000.0  4180032000.0  20230901         16       20     1.0
# 1588      1156054000.0  1144074000.0  20230901         12       13     0.0
# 8293      1156054000.0  1144066000.0  20230901         15       16     1.0
# 13179     1156054000.0  4623036000.0  20230901         17       22     1.0
# 14170     1156054000.0  1156066000.0  20230901         14       15     1.0
# ...                ...           ...       ...        ...      ...     ...
# 709176    1156054000.0  4139052000.0  20231015         21       23     1.0
# 709688    1156054000.0  1147062000.0  20231015         17       20     1.0
# 710559    1156054000.0  4139052000.0  20231015         21       22     0.0
# 711356    1156054000.0  4165025000.0  20231015         16       18     1.0
# 714284    1156054000.0  4122031000.0  20231015         17       20     1.0
#
#         age modal origin_purpose dest_purpose  od_dist_avg  od_duration_avg  \
# 330     2.0   0.0            4.0          5.0     234893.0            233.0
# 1588    4.0   0.0            3.0          1.0      18723.0             30.0
# 8293    2.0   0.0            3.0          3.0      30630.0             58.0
# 13179   2.0   0.0            5.0          0.0     866133.0            322.0
# 14170   5.0   0.0            3.0          0.0      40629.0             61.0
# ...     ...   ...            ...          ...          ...              ...
# 709176  2.0   0.0            5.0          0.0      90806.0            126.0
# 709688  1.0   0.0            3.0          0.0     164178.0            172.0
# 710559  2.0   0.0            4.0          0.0      87742.0             99.0
# 711356  3.0   0.0            4.0          0.0     245594.0            126.0
# 714284  1.0   5.0            5.0          4.0     216184.0            178.0
#
#         od_cnts origin
# 330           8     11
# 1588         13     11
# 8293          7     11
# 13179        15     11
# 14170         7     11
# ...         ...    ...
# 709176        5     11
# 709688        5     11
# 710559        5     11
# 711356        5     11
# 714284        5     11
#
# [136389 rows x 14 columns]

# %% [markdown]
# ### 강릉(1)

# %%
home_ga = get_home_data(od, '5115057200.0')
home_ga
# Out:
#        origin_hdong_cd dest_hdong_cd      date start_time end_time  gender  \
# 5575      5115057200.0  5115064500.0  20230901         18       18     1.0
# 58526     5115057200.0  5115059000.0  20230901         17       18     0.0
# 59107     5115057200.0  5115059000.0  20230901         15       15     0.0
# 65634     5115057200.0  5115059000.0  20230901         10       10     0.0
# 115425    5115057200.0  5115058000.0  20230901         12       13     0.0
# ...                ...           ...       ...        ...      ...     ...
# 680510    5115057200.0  5115059000.0  20231015         12       13     1.0
# 684082    5115057200.0  5115066500.0  20231015         13       13     1.0
# 691250    5115057200.0  5115052000.0  20231015         17       18     1.0
# 694731    5115057200.0  5115064500.0  20231015         17       18     1.0
# 709404    5115057200.0  5115025000.0  20231015         14       15     1.0
#
#         age modal origin_purpose dest_purpose  od_dist_avg  od_duration_avg  \
# 5575    0.0   1.0            4.0          0.0      33727.0             24.0
# 58526   0.0   4.0            3.0          0.0       8065.0             45.0
# 59107   1.0   0.0            4.0          4.0       1962.0              3.0
# 65634   1.0   0.0            4.0          4.0       5282.0              8.0
# 115425  1.0   0.0            4.0          4.0      42160.0             39.0
# ...     ...   ...            ...          ...          ...              ...
# 680510  1.0   0.0            4.0          0.0      23789.0             40.0
# 684082  2.0   1.0            3.0          3.0      11640.0             12.0
# 691250  2.0   0.0            4.0          0.0      26447.0             37.0
# 694731  3.0   0.0            4.0          4.0      19561.0             72.0
# 709404  1.0   0.0            5.0          5.0      34449.0             24.0
#
#         od_cnts origin
# 5575         14     51
# 58526        16     51
# 59107         8     51
# 65634         8     51
# 115425       28     51
# ...         ...    ...
# 680510        5     51
# 684082        5     51
# 691250        5     51
# 694731        5     51
# 709404        5     51
#
# [11538 rows x 14 columns]

# %% [markdown]
# ### 강릉(2)

# %%
home_gb = get_home_data(od, '5115058000.0')
home_gb
# Out:
#        origin_hdong_cd dest_hdong_cd      date start_time end_time  gender  \
# 3302      5115058000.0  5115066500.0  20230901         19       19     1.0
# 6500      5115058000.0  5115025000.0  20230901         13       15     1.0
# 46933     5115058000.0  5115066500.0  20230901         19       21     1.0
# 80944     5115058000.0  5115066500.0  20230901         16       16     1.0
# 81560     5115058000.0  5115066500.0  20230901         10       13     1.0
# ...                ...           ...       ...        ...      ...     ...
# 685147    5115058000.0  5115066500.0  20231015         12       13     1.0
# 691071    5115058000.0  1156058500.0  20231015         13       19     1.0
# 698302    5115058000.0  5115055000.0  20231015         20       22     0.0
# 703637    5115058000.0  5115025000.0  20231015         14       15     1.0
# 708484    5115058000.0  5115066500.0  20231015         21       22     1.0
#
#         age modal origin_purpose dest_purpose  od_dist_avg  od_duration_avg  \
# 3302    1.0   0.0            5.0          5.0      10232.0              7.0
# 6500    5.0   0.0            5.0          5.0     120666.0            114.0
# 46933   2.0   0.0            5.0          5.0     100035.0             99.0
# 80944   2.0   0.0            5.0          5.0      17613.0             12.0
# 81560   2.0   0.0            5.0          5.0     116246.0            161.0
# ...     ...   ...            ...          ...          ...              ...
# 685147  2.0   0.0            4.0          4.0      44245.0             78.0
# 691071  2.0   0.0            5.0          0.0     483037.0            378.0
# 698302  2.0   0.0            4.0          0.0     177680.0            130.0
# 703637  7.0   0.0            5.0          5.0      66479.0             67.0
# 708484  2.0   0.0            5.0          5.0       6899.0             80.0
#
#         od_cnts origin
# 3302          8     51
# 6500          9     51
# 46933        14     51
# 80944        10     51
# 81560        10     51
# ...         ...    ...
# 685147        5     51
# 691071        5     51
# 698302        5     51
# 703637        5     51
# 708484        5     51
#
# [29343 rows x 14 columns]

# %%
temp_2 = pd.concat([home_s, home_ga, home_gb])

# %%
temp_1 = pd.read_csv('data/temp.csv').drop(columns = 'Unnamed: 0')
temp_1
# Out:
#         origin_hdong_cd  dest_hdong_cd      date start_time end_time  gender  \
# 0          3.020055e+09   4.372039e+09  20230901      08:00    09:00     0.0
# 1          3.020055e+09   3.023052e+09  20230901      08:00    09:00     0.0
# 2          3.020055e+09   3.017059e+09  20230901      21:00    21:00     1.0
# 3          3.020055e+09   3.020054e+09  20230901      17:00    18:00     0.0
# 4          3.020055e+09   3.020054e+09  20230901      09:00    10:00     1.0
# ...                 ...            ...       ...        ...      ...     ...
# 268150     4.575034e+09   4.373025e+09  20231015      15:00    18:00     1.0
# 268151     4.575034e+09   4.511354e+09  20231015      17:00    17:00     0.0
# 268152     4.575034e+09   4.577034e+09  20231015      15:00    16:00     1.0
# 268153     4.575034e+09   4.575032e+09  20231015      12:00    12:00     1.0
# 268154     4.575034e+09   4.575032e+09  20231015      15:00    16:00     1.0
#
#         age  modal  origin_purpose  dest_purpose  od_dist_avg  \
# 0       3.0    0.0             4.0           4.0     153144.0
# 1       5.0    0.0             4.0           4.0      14091.0
# 2       2.0    0.0             3.0           0.0      10497.0
# 3       2.0    0.0             3.0           4.0      35412.0
# 4       1.0    0.0             5.0           5.0      15195.0
# ...     ...    ...             ...           ...          ...
# 268150  3.0    0.0             5.0           0.0     177750.0
# 268151  3.0    0.0             4.0           0.0      53267.0
# 268152  2.0    0.0             5.0           5.0      71232.0
# 268153  4.0    0.0             4.0           4.0      85154.0
# 268154  4.0    0.0             4.0           4.0     104175.0
#
#         od_duration_avg  od_cnts
# 0                  56.0        7
# 1                  31.0        8
# 2                  27.0        7
# 3                  49.0        7
# 4                  60.0       22
# ...                 ...      ...
# 268150            127.0        5
# 268151             40.0        5
# 268152             30.0        5
# 268153             45.0        6
# 268154            106.0        6
#
# [268155 rows x 13 columns]

# %%
temp_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268155 entries, 0 to 268154
# Data columns (total 13 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   origin_hdong_cd  268155 non-null  object
#  1   dest_hdong_cd    268155 non-null  object
#  2   date             268155 non-null  int64
#  3   start_time       268155 non-null  object
#  4   end_time         268155 non-null  object
#  5   gender           268155 non-null  float64
#  6   age              268155 non-null  float64
#  7   modal            268155 non-null  object
#  8   origin_purpose   268155 non-null  object
#  9   dest_purpose     268155 non-null  object
#  10  od_dist_avg      268155 non-null  float64
#  11  od_duration_avg  268155 non-null  float64
#  12  od_cnts          268155 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 26.6+ MB

# %%
temp_1.origin_hdong_cd = temp_1.origin_hdong_cd.astype('str')
temp_1.dest_hdong_cd = temp_1.dest_hdong_cd.astype('str')
temp_1.start_time = temp_1.start_time.str[:2]
temp_1.end_time = temp_1.end_time.str[:2]
temp_1.modal = temp_1.modal.astype('str')
temp_1.origin_purpose = temp_1.origin_purpose.astype('str')
temp_1.dest_purpose = temp_1.dest_purpose.astype('str')

# %%
temp_2 = temp_2.drop(columns = 'origin')
temp_2
# Out:
#        origin_hdong_cd dest_hdong_cd      date start_time end_time  gender  \
# 330       1156054000.0  4180032000.0  20230901         16       20     1.0
# 1588      1156054000.0  1144074000.0  20230901         12       13     0.0
# 8293      1156054000.0  1144066000.0  20230901         15       16     1.0
# 13179     1156054000.0  4623036000.0  20230901         17       22     1.0
# 14170     1156054000.0  1156066000.0  20230901         14       15     1.0
# ...                ...           ...       ...        ...      ...     ...
# 685147    5115058000.0  5115066500.0  20231015         12       13     1.0
# 691071    5115058000.0  1156058500.0  20231015         13       19     1.0
# 698302    5115058000.0  5115055000.0  20231015         20       22     0.0
# 703637    5115058000.0  5115025000.0  20231015         14       15     1.0
# 708484    5115058000.0  5115066500.0  20231015         21       22     1.0
#
#         age modal origin_purpose dest_purpose  od_dist_avg  od_duration_avg  \
# 330     2.0   0.0            4.0          5.0     234893.0            233.0
# 1588    4.0   0.0            3.0          1.0      18723.0             30.0
# 8293    2.0   0.0            3.0          3.0      30630.0             58.0
# 13179   2.0   0.0            5.0          0.0     866133.0            322.0
# 14170   5.0   0.0            3.0          0.0      40629.0             61.0
# ...     ...   ...            ...          ...          ...              ...
# 685147  2.0   0.0            4.0          4.0      44245.0             78.0
# 691071  2.0   0.0            5.0          0.0     483037.0            378.0
# 698302  2.0   0.0            4.0          0.0     177680.0            130.0
# 703637  7.0   0.0            5.0          5.0      66479.0             67.0
# 708484  2.0   0.0            5.0          5.0       6899.0             80.0
#
#         od_cnts
# 330           8
# 1588         13
# 8293          7
# 13179        15
# 14170         7
# ...         ...
# 685147        5
# 691071        5
# 698302        5
# 703637        5
# 708484        5
#
# [177270 rows x 13 columns]

# %%
home = pd.concat([temp_1, temp_2])
home
# Out:
#        origin_hdong_cd dest_hdong_cd      date start_time end_time  gender  \
# 0         3020055000.0  4372039000.0  20230901         08       09     0.0
# 1         3020055000.0  3023052500.0  20230901         08       09     0.0
# 2         3020055000.0  3017058800.0  20230901         21       21     1.0
# 3         3020055000.0  3020054000.0  20230901         17       18     0.0
# 4         3020055000.0  3020054000.0  20230901         09       10     1.0
# ...                ...           ...       ...        ...      ...     ...
# 685147    5115058000.0  5115066500.0  20231015         12       13     1.0
# 691071    5115058000.0  1156058500.0  20231015         13       19     1.0
# 698302    5115058000.0  5115055000.0  20231015         20       22     0.0
# 703637    5115058000.0  5115025000.0  20231015         14       15     1.0
# 708484    5115058000.0  5115066500.0  20231015         21       22     1.0
#
#         age modal origin_purpose dest_purpose  od_dist_avg  od_duration_avg  \
# 0       3.0   0.0            4.0          4.0     153144.0             56.0
# 1       5.0   0.0            4.0          4.0      14091.0             31.0
# 2       2.0   0.0            3.0          0.0      10497.0             27.0
# 3       2.0   0.0            3.0          4.0      35412.0             49.0
# 4       1.0   0.0            5.0          5.0      15195.0             60.0
# ...     ...   ...            ...          ...          ...              ...
# 685147  2.0   0.0            4.0          4.0      44245.0             78.0
# 691071  2.0   0.0            5.0          0.0     483037.0            378.0
# 698302  2.0   0.0            4.0          0.0     177680.0            130.0
# 703637  7.0   0.0            5.0          5.0      66479.0             67.0
# 708484  2.0   0.0            5.0          5.0       6899.0             80.0
#
#         od_cnts
# 0             7
# 1             8
# 2             7
# 3             7
# 4            22
# ...         ...
# 685147        5
# 691071        5
# 698302        5
# 703637        5
# 708484        5
#
# [445425 rows x 13 columns]

# %%
home.to_csv('data/home.csv')

# %%
df_visit = pd.read_csv('data/visit.csv')
df_home = pd.read_csv('data/home.csv')

final = pd.concat([df_visit, df_home]).drop(columns = 'Unnamed: 0')
final
# Out:
#         origin_hdong_cd  dest_hdong_cd      date start_time end_time  gender  \
# 0          1.117062e+09   3.020055e+09  20230902         12       16     1.0
# 1          1.168066e+09   3.020055e+09  20230902         10       14     0.0
# 2          1.150062e+09   3.020055e+09  20230902         10       14     0.0
# 3          1.171053e+09   3.020055e+09  20230902         10       13     0.0
# 4          1.165066e+09   3.020055e+09  20230902         17       19     0.0
# ...                 ...            ...       ...        ...      ...     ...
# 445420     5.115058e+09   5.115066e+09  20231015         12       13     1.0
# 445421     5.115058e+09   1.156058e+09  20231015         13       19     1.0
# 445422     5.115058e+09   5.115055e+09  20231015         20       22     0.0
# 445423     5.115058e+09   5.115025e+09  20231015         14       15     1.0
# 445424     5.115058e+09   5.115066e+09  20231015         21       22     1.0
#
#         age  modal  origin_purpose  dest_purpose  od_dist_avg  \
# 0       0.0    0.0             0.0           5.0     272315.0
# 1       0.0    0.0             0.0           5.0     262264.0
# 2       0.0    5.0             0.0           5.0     283507.0
# 3       1.0    0.0             2.0           4.0     294463.0
# 4       0.0    0.0             0.0           5.0     158665.0
# ...     ...    ...             ...           ...          ...
# 445420  2.0    0.0             4.0           4.0      44245.0
# 445421  2.0    0.0             5.0           0.0     483037.0
# 445422  2.0    0.0             4.0           0.0     177680.0
# 445423  7.0    0.0             5.0           5.0      66479.0
# 445424  2.0    0.0             5.0           5.0       6899.0
#
#         od_duration_avg  od_cnts  origin
# 0                 285.0       21    11.0
# 1                 233.0       27    11.0
# 2                 214.0       27    11.0
# 3                 172.0        9    11.0
# 4                 156.0       27    11.0
# ...                 ...      ...     ...
# 445420             78.0        5     NaN
# 445421            378.0        5     NaN
# 445422            130.0        5     NaN
# 445423             67.0        5     NaN
# 445424             80.0        5     NaN
#
# [588188 rows x 14 columns]

# %%
final.to_csv('data/OD_final.csv')

# %% [markdown]
# ## JOIN & MERGE

# %% [markdown]
# ### 방문 데이터

# %%
visit = pd.read_csv('data/visit.csv').drop(columns = ['Unnamed: 0', 'origin'])
visit
# Out:
#         origin_hdong_cd  dest_hdong_cd      date start_time end_time  gender  \
# 0          1.117062e+09   3.020055e+09  20230902         12       16     1.0
# 1          1.168066e+09   3.020055e+09  20230902         10       14     0.0
# 2          1.150062e+09   3.020055e+09  20230902         10       14     0.0
# 3          1.171053e+09   3.020055e+09  20230902         10       13     0.0
# 4          1.165066e+09   3.020055e+09  20230902         17       19     0.0
# ...                 ...            ...       ...        ...      ...     ...
# 142758     5.176034e+09   5.115058e+09  20231015      12:00    14:00     0.0
# 142759     5.115064e+09   5.115058e+09  20231015      11:00    12:00     0.0
# 142760     5.176038e+09   5.115058e+09  20231015      13:00    14:00     0.0
# 142761     5.115051e+09   5.115058e+09  20231015      11:00    11:00     0.0
# 142762     5.115066e+09   5.115058e+09  20231015      18:00    18:00     0.0
#
#         age  modal  origin_purpose  dest_purpose  od_dist_avg  \
# 0       0.0    0.0             0.0           5.0     272315.0
# 1       0.0    0.0             0.0           5.0     262264.0
# 2       0.0    5.0             0.0           5.0     283507.0
# 3       1.0    0.0             2.0           4.0     294463.0
# 4       0.0    0.0             0.0           5.0     158665.0
# ...     ...    ...             ...           ...          ...
# 142758  4.0    0.0             5.0           5.0     227797.0
# 142759  5.0    0.0             0.0           4.0      14623.0
# 142760  3.0    0.0             5.0           5.0      92098.0
# 142761  3.0    0.0             5.0           5.0      29664.0
# 142762  3.0    0.0             5.0           5.0       7594.0
#
#         od_duration_avg  od_cnts
# 0                 285.0       21
# 1                 233.0       27
# 2                 214.0       27
# 3                 172.0        9
# 4                 156.0       27
# ...                 ...      ...
# 142758             94.0        6
# 142759             22.0        5
# 142760             45.0        5
# 142761             19.0        5
# 142762              5.0        5
#
# [142763 rows x 13 columns]

# %%
visit.origin_hdong_cd = visit.origin_hdong_cd.astype('int').astype('str')
visit.dest_hdong_cd = visit.dest_hdong_cd.astype('int').astype('str')

# %%
visit.origin_hdong_cd.str[:2].unique()
# Out:
# array(['11', '26', '30', '45', '51'], dtype=object)

# %%
region_cd = {'11': 'S',
            '26': 'B',
            '30': 'D',
            '45': 'I',
            '51': 'G'}
visit['origin'] = visit.origin_hdong_cd.str[:2].map(region_cd)
visit
# Out:
#        origin_hdong_cd dest_hdong_cd      date start_time end_time  gender  \
# 0           1117062500    3020055000  20230902         12       16     1.0
# 1           1168065500    3020055000  20230902         10       14     0.0
# 2           1150062000    3020055000  20230902         10       14     0.0
# 3           1171053200    3020055000  20230902         10       13     0.0
# 4           1165066000    3020055000  20230902         17       19     0.0
# ...                ...           ...       ...        ...      ...     ...
# 142758      5176034000    5115058000  20231015      12:00    14:00     0.0
# 142759      5115064500    5115058000  20231015      11:00    12:00     0.0
# 142760      5176038000    5115058000  20231015      13:00    14:00     0.0
# 142761      5115051000    5115058000  20231015      11:00    11:00     0.0
# 142762      5115066500    5115058000  20231015      18:00    18:00     0.0
#
#         age  modal  origin_purpose  dest_purpose  od_dist_avg  \
# 0       0.0    0.0             0.0           5.0     272315.0
# 1       0.0    0.0             0.0           5.0     262264.0
# 2       0.0    5.0             0.0           5.0     283507.0
# 3       1.0    0.0             2.0           4.0     294463.0
# 4       0.0    0.0             0.0           5.0     158665.0
# ...     ...    ...             ...           ...          ...
# 142758  4.0    0.0             5.0           5.0     227797.0
# 142759  5.0    0.0             0.0           4.0      14623.0
# 142760  3.0    0.0             5.0           5.0      92098.0
# 142761  3.0    0.0             5.0           5.0      29664.0
# 142762  3.0    0.0             5.0           5.0       7594.0
#
#         od_duration_avg  od_cnts origin
# 0                 285.0       21      S
# 1                 233.0       27      S
# 2                 214.0       27      S
# 3                 172.0        9      S
# 4                 156.0       27      S
# ...                 ...      ...    ...
# 142758             94.0        6      G
# 142759             22.0        5      G
# 142760             45.0        5      G
# 142761             19.0        5      G
# 142762              5.0        5      G
#
# [142763 rows x 14 columns]

# %%
hdong_cd = {'3020055000': 'D',
            '2635052000': 'B',
            '4575034000': 'I',
            '1156054000': 'S',
            '5115057200': 'GA',
            '5115058000': 'GB'}
visit['dest'] = visit.dest_hdong_cd.map(hdong_cd)
visit
# Out:
#        origin_hdong_cd dest_hdong_cd      date start_time end_time  gender  \
# 0           1117062500    3020055000  20230902         12       16     1.0
# 1           1168065500    3020055000  20230902         10       14     0.0
# 2           1150062000    3020055000  20230902         10       14     0.0
# 3           1171053200    3020055000  20230902         10       13     0.0
# 4           1165066000    3020055000  20230902         17       19     0.0
# ...                ...           ...       ...        ...      ...     ...
# 142758      5176034000    5115058000  20231015      12:00    14:00     0.0
# 142759      5115064500    5115058000  20231015      11:00    12:00     0.0
# 142760      5176038000    5115058000  20231015      13:00    14:00     0.0
# 142761      5115051000    5115058000  20231015      11:00    11:00     0.0
# 142762      5115066500    5115058000  20231015      18:00    18:00     0.0
#
#         age  modal  origin_purpose  dest_purpose  od_dist_avg  \
# 0       0.0    0.0             0.0           5.0     272315.0
# 1       0.0    0.0             0.0           5.0     262264.0
# 2       0.0    5.0             0.0           5.0     283507.0
# 3       1.0    0.0             2.0           4.0     294463.0
# 4       0.0    0.0             0.0           5.0     158665.0
# ...     ...    ...             ...           ...          ...
# 142758  4.0    0.0             5.0           5.0     227797.0
# 142759  5.0    0.0             0.0           4.0      14623.0
# 142760  3.0    0.0             5.0           5.0      92098.0
# 142761  3.0    0.0             5.0           5.0      29664.0
# 142762  3.0    0.0             5.0           5.0       7594.0
#
#         od_duration_avg  od_cnts origin dest
# 0                 285.0       21      S    D
# 1                 233.0       27      S    D
# 2                 214.0       27      S    D
# 3                 172.0        9      S    D
# 4                 156.0       27      S    D
# ...                 ...      ...    ...  ...
# 142758             94.0        6      G   GB
# 142759             22.0        5      G   GB
# 142760             45.0        5      G   GB
# 142761             19.0        5      G   GB
# 142762              5.0        5      G   GB
#
# [142763 rows x 15 columns]

# %%
visit.start_time = visit.start_time.str[:2].astype('int')
visit.end_time = visit.end_time.str[:2].astype('int')

# %%
visit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142763 entries, 0 to 142762
# Data columns (total 15 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   origin_hdong_cd  142763 non-null  object
#  1   dest_hdong_cd    142763 non-null  object
#  2   date             142763 non-null  int64
#  3   start_time       142763 non-null  int64
#  4   end_time         142763 non-null  int64
#  5   gender           142763 non-null  float64
#  6   age              142763 non-null  float64
#  7   modal            142763 non-null  float64
#  8   origin_purpose   142696 non-null  float64
#  9   dest_purpose     142763 non-null  float64
#  10  od_dist_avg      142763 non-null  float64
#  11  od_duration_avg  142763 non-null  float64
#  12  od_cnts          142763 non-null  int64
#  13  origin           142763 non-null  object
#  14  dest             142763 non-null  object
# dtypes: float64(7), int64(4), object(4)
# memory usage: 16.3+ MB

# %% [markdown]
# ### 귀가 데이터

# %%
home = pd.read_csv('data/home.csv').drop(columns = 'Unnamed: 0')
home
# Out:
#         origin_hdong_cd  dest_hdong_cd      date  start_time  end_time  \
# 0          3.020055e+09   4.372039e+09  20230901           8         9
# 1          3.020055e+09   3.023052e+09  20230901           8         9
# 2          3.020055e+09   3.017059e+09  20230901          21        21
# 3          3.020055e+09   3.020054e+09  20230901          17        18
# 4          3.020055e+09   3.020054e+09  20230901           9        10
# ...                 ...            ...       ...         ...       ...
# 445420     5.115058e+09   5.115066e+09  20231015          12        13
# 445421     5.115058e+09   1.156058e+09  20231015          13        19
# 445422     5.115058e+09   5.115055e+09  20231015          20        22
# 445423     5.115058e+09   5.115025e+09  20231015          14        15
# 445424     5.115058e+09   5.115066e+09  20231015          21        22
#
#         gender  age  modal  origin_purpose  dest_purpose  od_dist_avg  \
# 0          0.0  3.0    0.0             4.0           4.0     153144.0
# 1          0.0  5.0    0.0             4.0           4.0      14091.0
# 2          1.0  2.0    0.0             3.0           0.0      10497.0
# 3          0.0  2.0    0.0             3.0           4.0      35412.0
# 4          1.0  1.0    0.0             5.0           5.0      15195.0
# ...        ...  ...    ...             ...           ...          ...
# 445420     1.0  2.0    0.0             4.0           4.0      44245.0
# 445421     1.0  2.0    0.0             5.0           0.0     483037.0
# 445422     0.0  2.0    0.0             4.0           0.0     177680.0
# 445423     1.0  7.0    0.0             5.0           5.0      66479.0
# 445424     1.0  2.0    0.0             5.0           5.0       6899.0
#
#         od_duration_avg  od_cnts
# 0                  56.0        7
# 1                  31.0        8
# 2                  27.0        7
# 3                  49.0        7
# 4                  60.0       22
# ...                 ...      ...
# 445420             78.0        5
# 445421            378.0        5
# 445422            130.0        5
# 445423             67.0        5
# 445424             80.0        5
#
# [445425 rows x 13 columns]

# %%
home.origin_hdong_cd = home.origin_hdong_cd.astype('int').astype('str')
home.dest_hdong_cd = home.dest_hdong_cd.astype('int').astype('str')

# %%
home.origin_hdong_cd.unique()
# Out:
# array(['3020055000', '2635052000', '4575034000', '1156054000',
#        '5115057200', '5115058000'], dtype=object)

# %%
hdong_cd = {'3020055000': 'D',
            '2635052000': 'B',
            '4575034000': 'I',
            '1156054000': 'S',
            '5115057200': 'GA',
            '5115058000': 'GB'}
home['dest'] = home.origin_hdong_cd.map(hdong_cd)
home
# Out:
#        origin_hdong_cd dest_hdong_cd      date  start_time  end_time  gender  \
# 0           3020055000    4372039000  20230901           8         9     0.0
# 1           3020055000    3023052500  20230901           8         9     0.0
# 2           3020055000    3017058800  20230901          21        21     1.0
# 3           3020055000    3020054000  20230901          17        18     0.0
# 4           3020055000    3020054000  20230901           9        10     1.0
# ...                ...           ...       ...         ...       ...     ...
# 445420      5115058000    5115066500  20231015          12        13     1.0
# 445421      5115058000    1156058500  20231015          13        19     1.0
# 445422      5115058000    5115055000  20231015          20        22     0.0
# 445423      5115058000    5115025000  20231015          14        15     1.0
# 445424      5115058000    5115066500  20231015          21        22     1.0
#
#         age  modal  origin_purpose  dest_purpose  od_dist_avg  \
# 0       3.0    0.0             4.0           4.0     153144.0
# 1       5.0    0.0             4.0           4.0      14091.0
# 2       2.0    0.0             3.0           0.0      10497.0
# 3       2.0    0.0             3.0           4.0      35412.0
# 4       1.0    0.0             5.0           5.0      15195.0
# ...     ...    ...             ...           ...          ...
# 445420  2.0    0.0             4.0           4.0      44245.0
# 445421  2.0    0.0             5.0           0.0     483037.0
# 445422  2.0    0.0             4.0           0.0     177680.0
# 445423  7.0    0.0             5.0           5.0      66479.0
# 445424  2.0    0.0             5.0           5.0       6899.0
#
#         od_duration_avg  od_cnts dest
# 0                  56.0        7    D
# 1                  31.0        8    D
# 2                  27.0        7    D
# 3                  49.0        7    D
# 4                  60.0       22    D
# ...                 ...      ...  ...
# 445420             78.0        5   GB
# 445421            378.0        5   GB
# 445422            130.0        5   GB
# 445423             67.0        5   GB
# 445424             80.0        5   GB
#
# [445425 rows x 14 columns]

# %%
home.isna().sum()
# Out:
# origin_hdong_cd    0
# dest_hdong_cd      0
# date               0
# start_time         0
# end_time           0
# gender             0
# age                0
# modal              0
# origin_purpose     0
# dest_purpose       0
# od_dist_avg        0
# od_duration_avg    0
# od_cnts            0
# dest               0
# dtype: int64

# %%
region_cd = {'11': 'S',
            '26': 'B',
            '30': 'D',
            '45': 'I',
            '51': 'G'}
home['origin'] = home.dest_hdong_cd.str[:2].map(region_cd)

# %%
home.origin.unique()
# Out:
# array([nan, 'D', 'I', 'S', 'B', 'G'], dtype=object)

# %%
home = home.dropna(subset = 'origin', how = 'any')
home.isna().sum()
# Out:
# origin_hdong_cd    0
# dest_hdong_cd      0
# date               0
# start_time         0
# end_time           0
# gender             0
# age                0
# modal              0
# origin_purpose     0
# dest_purpose       0
# od_dist_avg        0
# od_duration_avg    0
# od_cnts            0
# dest               0
# origin             0
# dtype: int64

# %%
home.isna().sum()
# Out:
# origin_hdong_cd    0
# dest_hdong_cd      0
# date               0
# start_time         0
# end_time           0
# gender             0
# age                0
# modal              0
# origin_purpose     0
# dest_purpose       0
# od_dist_avg        0
# od_duration_avg    0
# od_cnts            0
# dest               0
# origin             0
# dtype: int64

# %%
home = home[['origin_hdong_cd', 'dest_hdong_cd', 'date', 'start_time', 'end_time', 'gender', 'age', 'modal', 'origin_purpose', 'dest_purpose', 'od_dist_avg', 'od_duration_avg', 'od_cnts', 'origin', 'dest']]
home.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 375829 entries, 1 to 445424
# Data columns (total 15 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   origin_hdong_cd  375829 non-null  object
#  1   dest_hdong_cd    375829 non-null  object
#  2   date             375829 non-null  int64
#  3   start_time       375829 non-null  int64
#  4   end_time         375829 non-null  int64
#  5   gender           375829 non-null  float64
#  6   age              375829 non-null  float64
#  7   modal            375829 non-null  float64
#  8   origin_purpose   375829 non-null  float64
#  9   dest_purpose     375829 non-null  float64
#  10  od_dist_avg      375829 non-null  float64
#  11  od_duration_avg  375829 non-null  float64
#  12  od_cnts          375829 non-null  int64
#  13  origin           375829 non-null  object
#  14  dest             375829 non-null  object
# dtypes: float64(7), int64(4), object(4)
# memory usage: 45.9+ MB

# %% [markdown]
# ### visit + home = od_final

# %%
od_final = pd.concat([visit, home])
od_final
# Out:
#        origin_hdong_cd dest_hdong_cd      date  start_time  end_time  gender  \
# 0           1117062500    3020055000  20230902          12        16     1.0
# 1           1168065500    3020055000  20230902          10        14     0.0
# 2           1150062000    3020055000  20230902          10        14     0.0
# 3           1171053200    3020055000  20230902          10        13     0.0
# 4           1165066000    3020055000  20230902          17        19     0.0
# ...                ...           ...       ...         ...       ...     ...
# 445420      5115058000    5115066500  20231015          12        13     1.0
# 445421      5115058000    1156058500  20231015          13        19     1.0
# 445422      5115058000    5115055000  20231015          20        22     0.0
# 445423      5115058000    5115025000  20231015          14        15     1.0
# 445424      5115058000    5115066500  20231015          21        22     1.0
#
#         age  modal  origin_purpose  dest_purpose  od_dist_avg  \
# 0       0.0    0.0             0.0           5.0     272315.0
# 1       0.0    0.0             0.0           5.0     262264.0
# 2       0.0    5.0             0.0           5.0     283507.0
# 3       1.0    0.0             2.0           4.0     294463.0
# 4       0.0    0.0             0.0           5.0     158665.0
# ...     ...    ...             ...           ...          ...
# 445420  2.0    0.0             4.0           4.0      44245.0
# 445421  2.0    0.0             5.0           0.0     483037.0
# 445422  2.0    0.0             4.0           0.0     177680.0
# 445423  7.0    0.0             5.0           5.0      66479.0
# 445424  2.0    0.0             5.0           5.0       6899.0
#
#         od_duration_avg  od_cnts origin dest
# 0                 285.0       21      S    D
# 1                 233.0       27      S    D
# 2                 214.0       27      S    D
# 3                 172.0        9      S    D
# 4                 156.0       27      S    D
# ...                 ...      ...    ...  ...
# 445420             78.0        5      G   GB
# 445421            378.0        5      S   GB
# 445422            130.0        5      G   GB
# 445423             67.0        5      G   GB
# 445424             80.0        5      G   GB
#
# [518592 rows x 15 columns]

# %%
od_final = od_final.dropna(subset = 'origin_purpose', how = 'any')
od_final.isna().sum()
# Out:
# origin_hdong_cd    0
# dest_hdong_cd      0
# date               0
# start_time         0
# end_time           0
# gender             0
# age                0
# modal              0
# origin_purpose     0
# dest_purpose       0
# od_dist_avg        0
# od_duration_avg    0
# od_cnts            0
# origin             0
# dest               0
# dtype: int64

# %%
od_final.date = od_final.date.astype('str')
od_final.start_time = od_final.start_time.astype('int')
od_final.end_time = od_final.end_time.astype('int')
od_final.gender = od_final.gender.astype('int').astype('str')
od_final.age = od_final.age.astype('int')
od_final.modal = od_final.modal.astype('int').astype('str')
od_final.origin_purpose = od_final.origin_purpose.astype('str')
od_final.dest_purpose = od_final.dest_purpose.astype('int').astype('str')
# Out:
# <ipython-input-250-6d1a377f5ebb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   od_final.date = od_final.date.astype('str')
# <ipython-input-250-6d1a377f5ebb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   od_final.start_time = od_final.start_time.astype('int')
# <ipython-input-250-6d1a377f5ebb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   od_final.end_time = od_final.end_time.astype('int')
# <ipython-input-250-6d1a377f5ebb>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   od_final.gender = od_final.gender.astype('int').astype('str')
# <ipython-input-250-6d1a377f5ebb>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   od_final.age = od_final.age.astype('int')
# <ipython-input-250-6d1a377f5ebb>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   od_final.modal = od_final.modal.astype('int').astype('str')
# <ipython-input-250-6d1a377f5ebb>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   od_final.origin_purpose = od_final.origin_purpose.astype('str')
# <ipython-input-250-6d1a377f5ebb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   od_final.dest_purpose = od_final.dest_purpose.astype('int').astype('str')

# %%
od_final.shape
# Out:
# (518525, 15)

# %%
od_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 518525 entries, 0 to 445424
# Data columns (total 15 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   origin_hdong_cd  518525 non-null  object
#  1   dest_hdong_cd    518525 non-null  object
#  2   date             518525 non-null  object
#  3   start_time       518525 non-null  int64
#  4   end_time         518525 non-null  int64
#  5   gender           518525 non-null  object
#  6   age              518525 non-null  int64
#  7   modal            518525 non-null  object
#  8   origin_purpose   518525 non-null  object
#  9   dest_purpose     518525 non-null  object
#  10  od_dist_avg      518525 non-null  float64
#  11  od_duration_avg  518525 non-null  float64
#  12  od_cnts          518525 non-null  int64
#  13  origin           518525 non-null  object
#  14  dest             518525 non-null  object
# dtypes: float64(2), int64(4), object(9)
# memory usage: 63.3+ MB

# %%
od = od_final[['origin', 'dest', 'date', 'start_time', 'end_time', 'gender', 'age', 'modal', 'origin_purpose', 'dest_purpose', 'od_dist_avg', 'od_duration_avg', 'od_cnts']]
od
# Out:
#        origin dest      date  start_time  end_time gender  age modal  \
# 0           S    D  20230902          12        16      1    0     0
# 1           S    D  20230902          10        14      0    0     0
# 2           S    D  20230902          10        14      0    0     5
# 3           S    D  20230902          10        13      0    1     0
# 4           S    D  20230902          17        19      0    0     0
# ...       ...  ...       ...         ...       ...    ...  ...   ...
# 445420      G   GB  20231015          12        13      1    2     0
# 445421      S   GB  20231015          13        19      1    2     0
# 445422      G   GB  20231015          20        22      0    2     0
# 445423      G   GB  20231015          14        15      1    7     0
# 445424      G   GB  20231015          21        22      1    2     0
#
#        origin_purpose dest_purpose  od_dist_avg  od_duration_avg  od_cnts
# 0                 0.0            5     272315.0            285.0       21
# 1                 0.0            5     262264.0            233.0       27
# 2                 0.0            5     283507.0            214.0       27
# 3                 2.0            4     294463.0            172.0        9
# 4                 0.0            5     158665.0            156.0       27
# ...               ...          ...          ...              ...      ...
# 445420            4.0            4      44245.0             78.0        5
# 445421            5.0            0     483037.0            378.0        5
# 445422            4.0            0     177680.0            130.0        5
# 445423            5.0            5      66479.0             67.0        5
# 445424            5.0            5       6899.0             80.0        5
#
# [518525 rows x 13 columns]

# %%
print(od.origin.unique())
print(od.dest.unique() )
# Out:
# ['S' 'B' 'D' 'I' 'G']
# ['D' 'B' 'I' 'S' 'GA' 'GB']

# %%
od.origin = od.origin.map({'GA': 'G',
                    'GB': 'G'})
od.origin.unique()
# Out:
# <ipython-input-132-f8b8b25a8a81>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   od.origin = od.origin.map({'GA': 'G',
# array([nan, 'G', 'B'], dtype=object)

# %%
transit = pd.read_csv('data/transit_columns2.csv')
transit
# Out:
#      구분  max_time  min_time  num_trainsit_methods  median_time     예상 배차시간  \
# 0    BB      5413      2758                     2       3066.0  287.931818
# 1    BD     14581      7437                     4       8565.0  195.618421
# 2   BGA     23378      2471                     5      22828.0  331.551724
# 3   BGB     24011      2511                     5      22093.0  193.017241
# 4    BI     21593     16229                     5      18940.0  290.399015
# 5    BS     23197     11864                     3      16002.5  286.430769
# 6    DD      4145      1958                     2       2387.0  210.227273
# 7   GGA      2488      1904                     2       2215.0  442.641509
# 8   GGB      6124      1844                     3       2155.0  223.325581
# 9    II       185       107                     2        265.0  218.333333
# 10   SB     23487      9803                     4      20332.0  276.149733
# 11   SD     11411      6467                     3       9568.0  205.338710
# 12  SGA    204386      8160                     3      11640.0  696.526316
# 13  SGB     16968      9004                     5      13121.5  211.992126
# 14   SI     17010      9309                     4      14428.0  481.507433
# 15   SS      2578      1542                     2       1717.0  199.423729
#
#     최대 이동거리  최소 이동거리  이동거리 중간값  최대 교통수단 수      환승횟수  마지막 도보시간 중간값  마지막 도보시간 평균
# 0     25962    13040     13699          3  3.013699      3.300000     8.600000
# 1    211083   207278    209009          3  4.298507      4.150000     5.050000
# 2    308473   299594    303565          3  5.165605      2.333333    17.250000
# 3    311981    30419    304010          3  5.165605      2.333333     5.200000
# 4    262567   230051    256362          4  5.705405      3.783333    21.733333
# 5    338414    33448    335721          3  3.867257      4.550000     3.650000
# 6     15483     8619     10085          2  2.958904      3.841667     5.050000
# 7      5725     3754      4508          1  2.965909      3.100000    17.250000
# 8     31749     7262      7296          2  3.037209      3.100000     4.083333
# 9    347738      115     13547          1  3.000000      1.966667     7.883333
# 10   369479   340827    340841          4  4.082317      5.050000    10.066667
# 11   154480   150675    152219          3  4.201835      4.150000     4.150000
# 12   220586   191468    204386          3  3.305556      4.000000    29.000000
# 13   206356   177862    182214          4  5.861171      3.983333     4.083333
# 14   226695   216432    221938          3  3.318584      4.383333     7.883333
# 15    10875     6202      6775          2  2.969388      3.650000     5.150000

# %%
transit['origin'] = transit.구분.str[0]
transit['dest'] = transit.구분.str[1:]
transit = transit.drop(columns = '구분')
transit
# Out:
#     max_time  min_time  num_trainsit_methods  median_time     예상 배차시간  \
# 0       5413      2758                     2       3066.0  287.931818
# 1      14581      7437                     4       8565.0  195.618421
# 2      23378      2471                     5      22828.0  331.551724
# 3      24011      2511                     5      22093.0  193.017241
# 4      21593     16229                     5      18940.0  290.399015
# 5      23197     11864                     3      16002.5  286.430769
# 6       4145      1958                     2       2387.0  210.227273
# 7       2488      1904                     2       2215.0  442.641509
# 8       6124      1844                     3       2155.0  223.325581
# 9        185       107                     2        265.0  218.333333
# 10     23487      9803                     4      20332.0  276.149733
# 11     11411      6467                     3       9568.0  205.338710
# 12    204386      8160                     3      11640.0  696.526316
# 13     16968      9004                     5      13121.5  211.992126
# 14     17010      9309                     4      14428.0  481.507433
# 15      2578      1542                     2       1717.0  199.423729
#
#     최대 이동거리  최소 이동거리  이동거리 중간값  최대 교통수단 수      환승횟수  마지막 도보시간 중간값  \
# 0     25962    13040     13699          3  3.013699      3.300000
# 1    211083   207278    209009          3  4.298507      4.150000
# 2    308473   299594    303565          3  5.165605      2.333333
# 3    311981    30419    304010          3  5.165605      2.333333
# 4    262567   230051    256362          4  5.705405      3.783333
# 5    338414    33448    335721          3  3.867257      4.550000
# 6     15483     8619     10085          2  2.958904      3.841667
# 7      5725     3754      4508          1  2.965909      3.100000
# 8     31749     7262      7296          2  3.037209      3.100000
# 9    347738      115     13547          1  3.000000      1.966667
# 10   369479   340827    340841          4  4.082317      5.050000
# 11   154480   150675    152219          3  4.201835      4.150000
# 12   220586   191468    204386          3  3.305556      4.000000
# 13   206356   177862    182214          4  5.861171      3.983333
# 14   226695   216432    221938          3  3.318584      4.383333
# 15    10875     6202      6775          2  2.969388      3.650000
#
#     마지막 도보시간 평균 origin dest
# 0      8.600000      B    B
# 1      5.050000      B    D
# 2     17.250000      B   GA
# 3      5.200000      B   GB
# 4     21.733333      B    I
# 5      3.650000      B    S
# 6      5.050000      D    D
# 7     17.250000      G   GA
# 8      4.083333      G   GB
# 9      7.883333      I    I
# 10    10.066667      S    B
# 11     4.150000      S    D
# 12    29.000000      S   GA
# 13     4.083333      S   GB
# 14     7.883333      S    I
# 15     5.150000      S    S

# %%
transit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   max_time              16 non-null     int64
#  1   min_time              16 non-null     int64
#  2   num_trainsit_methods  16 non-null     int64
#  3   median_time           16 non-null     float64
#  4   예상 배차시간               16 non-null     float64
#  5   최대 이동거리               16 non-null     int64
#  6   최소 이동거리               16 non-null     int64
#  7   이동거리 중간값              16 non-null     int64
#  8   최대 교통수단 수             16 non-null     int64
#  9   환승횟수                  16 non-null     float64
#  10  마지막 도보시간 중간값          16 non-null     float64
#  11  마지막 도보시간 평균           16 non-null     float64
#  12  origin                16 non-null     object
#  13  dest                  16 non-null     object
# dtypes: float64(5), int64(7), object(2)
# memory usage: 1.9+ KB

# %%
transit = transit[['origin', 'dest', 'max_time', 'min_time', 'num_trainsit_methods', 'median_time', '예상 배차시간', '최대 이동거리', '이동거리 중간값',
                   '최대 교통수단 수', '환승횟수', '마지막 도보시간 중간값', '마지막 도보시간 평균']]
transit
# Out:
#    origin dest  max_time  min_time  num_trainsit_methods  median_time  \
# 0       B    B      5413      2758                     2       3066.0
# 1       B    D     14581      7437                     4       8565.0
# 2       B   GA     23378      2471                     5      22828.0
# 3       B   GB     24011      2511                     5      22093.0
# 4       B    I     21593     16229                     5      18940.0
# 5       B    S     23197     11864                     3      16002.5
# 6       D    D      4145      1958                     2       2387.0
# 7       G   GA      2488      1904                     2       2215.0
# 8       G   GB      6124      1844                     3       2155.0
# 9       I    I       185       107                     2        265.0
# 10      S    B     23487      9803                     4      20332.0
# 11      S    D     11411      6467                     3       9568.0
# 12      S   GA    204386      8160                     3      11640.0
# 13      S   GB     16968      9004                     5      13121.5
# 14      S    I     17010      9309                     4      14428.0
# 15      S    S      2578      1542                     2       1717.0
#
#        예상 배차시간  최대 이동거리  이동거리 중간값  최대 교통수단 수      환승횟수  마지막 도보시간 중간값  \
# 0   287.931818    25962     13699          3  3.013699      3.300000
# 1   195.618421   211083    209009          3  4.298507      4.150000
# 2   331.551724   308473    303565          3  5.165605      2.333333
# 3   193.017241   311981    304010          3  5.165605      2.333333
# 4   290.399015   262567    256362          4  5.705405      3.783333
# 5   286.430769   338414    335721          3  3.867257      4.550000
# 6   210.227273    15483     10085          2  2.958904      3.841667
# 7   442.641509     5725      4508          1  2.965909      3.100000
# 8   223.325581    31749      7296          2  3.037209      3.100000
# 9   218.333333   347738     13547          1  3.000000      1.966667
# 10  276.149733   369479    340841          4  4.082317      5.050000
# 11  205.338710   154480    152219          3  4.201835      4.150000
# 12  696.526316   220586    204386          3  3.305556      4.000000
# 13  211.992126   206356    182214          4  5.861171      3.983333
# 14  481.507433   226695    221938          3  3.318584      4.383333
# 15  199.423729    10875      6775          2  2.969388      3.650000
#
#     마지막 도보시간 평균
# 0      8.600000
# 1      5.050000
# 2     17.250000
# 3      5.200000
# 4     21.733333
# 5      3.650000
# 6      5.050000
# 7     17.250000
# 8      4.083333
# 9      7.883333
# 10    10.066667
# 11     4.150000
# 12    29.000000
# 13     4.083333
# 14     7.883333
# 15     5.150000

# %%
transit.columns = ['origin', 'dest', 'max_time', 'min_time', 'num_transit_methods', 'median_time', 'predict_time', 'max_distance', 'median_distance', 'max_transit_methods', 'num_transfer', 'median_last_walk', 'avg_last_walk']
transit
# Out:
#    origin dest  max_time  min_time  num_transit_methods  median_time  \
# 0       B    B      5413      2758                    2       3066.0
# 1       B    D     14581      7437                    4       8565.0
# 2       B   GA     23378      2471                    5      22828.0
# 3       B   GB     24011      2511                    5      22093.0
# 4       B    I     21593     16229                    5      18940.0
# 5       B    S     23197     11864                    3      16002.5
# 6       D    D      4145      1958                    2       2387.0
# 7       G   GA      2488      1904                    2       2215.0
# 8       G   GB      6124      1844                    3       2155.0
# 9       I    I       185       107                    2        265.0
# 10      S    B     23487      9803                    4      20332.0
# 11      S    D     11411      6467                    3       9568.0
# 12      S   GA    204386      8160                    3      11640.0
# 13      S   GB     16968      9004                    5      13121.5
# 14      S    I     17010      9309                    4      14428.0
# 15      S    S      2578      1542                    2       1717.0
#
#     predict_time  max_distance  median_distance  max_transit_methods  \
# 0     287.931818         25962            13699                    3
# 1     195.618421        211083           209009                    3
# 2     331.551724        308473           303565                    3
# 3     193.017241        311981           304010                    3
# 4     290.399015        262567           256362                    4
# 5     286.430769        338414           335721                    3
# 6     210.227273         15483            10085                    2
# 7     442.641509          5725             4508                    1
# 8     223.325581         31749             7296                    2
# 9     218.333333        347738            13547                    1
# 10    276.149733        369479           340841                    4
# 11    205.338710        154480           152219                    3
# 12    696.526316        220586           204386                    3
# 13    211.992126        206356           182214                    4
# 14    481.507433        226695           221938                    3
# 15    199.423729         10875             6775                    2
#
#     num_transfer  median_last_walk  avg_last_walk
# 0       3.013699          3.300000       8.600000
# 1       4.298507          4.150000       5.050000
# 2       5.165605          2.333333      17.250000
# 3       5.165605          2.333333       5.200000
# 4       5.705405          3.783333      21.733333
# 5       3.867257          4.550000       3.650000
# 6       2.958904          3.841667       5.050000
# 7       2.965909          3.100000      17.250000
# 8       3.037209          3.100000       4.083333
# 9       3.000000          1.966667       7.883333
# 10      4.082317          5.050000      10.066667
# 11      4.201835          4.150000       4.150000
# 12      3.305556          4.000000      29.000000
# 13      5.861171          3.983333       4.083333
# 14      3.318584          4.383333       7.883333
# 15      2.969388          3.650000       5.150000

# %%
od
# Out:
#        origin dest      date  start_time  end_time gender  age modal  \
# 0           S    D  20230902          12        16      1    0     0
# 1           S    D  20230902          10        14      0    0     0
# 2           S    D  20230902          10        14      0    0     5
# 3           S    D  20230902          10        13      0    1     0
# 4           S    D  20230902          17        19      0    0     0
# ...       ...  ...       ...         ...       ...    ...  ...   ...
# 445420      G   GB  20231015          12        13      1    2     0
# 445421      S   GB  20231015          13        19      1    2     0
# 445422      G   GB  20231015          20        22      0    2     0
# 445423      G   GB  20231015          14        15      1    7     0
# 445424      G   GB  20231015          21        22      1    2     0
#
#        origin_purpose dest_purpose  od_dist_avg  od_duration_avg  od_cnts
# 0                 0.0            5     272315.0            285.0       21
# 1                 0.0            5     262264.0            233.0       27
# 2                 0.0            5     283507.0            214.0       27
# 3                 2.0            4     294463.0            172.0        9
# 4                 0.0            5     158665.0            156.0       27
# ...               ...          ...          ...              ...      ...
# 445420            4.0            4      44245.0             78.0        5
# 445421            5.0            0     483037.0            378.0        5
# 445422            4.0            0     177680.0            130.0        5
# 445423            5.0            5      66479.0             67.0        5
# 445424            5.0            5       6899.0             80.0        5
#
# [518525 rows x 13 columns]

# %%
tot = pd.merge(od, transit, how = 'left', on = ['origin', 'dest'])
tot
# Out:
#        origin dest      date  start_time  end_time gender  age modal  \
# 0           S    D  20230902          12        16      1    0     0
# 1           S    D  20230902          10        14      0    0     0
# 2           S    D  20230902          10        14      0    0     5
# 3           S    D  20230902          10        13      0    1     0
# 4           S    D  20230902          17        19      0    0     0
# ...       ...  ...       ...         ...       ...    ...  ...   ...
# 518520      G   GB  20231015          12        13      1    2     0
# 518521      S   GB  20231015          13        19      1    2     0
# 518522      G   GB  20231015          20        22      0    2     0
# 518523      G   GB  20231015          14        15      1    7     0
# 518524      G   GB  20231015          21        22      1    2     0
#
#        origin_purpose dest_purpose  ...  min_time  num_transit_methods  \
# 0                 0.0            5  ...    6467.0                  3.0
# 1                 0.0            5  ...    6467.0                  3.0
# 2                 0.0            5  ...    6467.0                  3.0
# 3                 2.0            4  ...    6467.0                  3.0
# 4                 0.0            5  ...    6467.0                  3.0
# ...               ...          ...  ...       ...                  ...
# 518520            4.0            4  ...    1844.0                  3.0
# 518521            5.0            0  ...    9004.0                  5.0
# 518522            4.0            0  ...    1844.0                  3.0
# 518523            5.0            5  ...    1844.0                  3.0
# 518524            5.0            5  ...    1844.0                  3.0
#
#         median_time  predict_time  max_distance  median_distance  \
# 0            9568.0    205.338710      154480.0         152219.0
# 1            9568.0    205.338710      154480.0         152219.0
# 2            9568.0    205.338710      154480.0         152219.0
# 3            9568.0    205.338710      154480.0         152219.0
# 4            9568.0    205.338710      154480.0         152219.0
# ...             ...           ...           ...              ...
# 518520       2155.0    223.325581       31749.0           7296.0
# 518521      13121.5    211.992126      206356.0         182214.0
# 518522       2155.0    223.325581       31749.0           7296.0
# 518523       2155.0    223.325581       31749.0           7296.0
# 518524       2155.0    223.325581       31749.0           7296.0
#
#         max_transit_methods  num_transfer  median_last_walk  avg_last_walk
# 0                       3.0      4.201835          4.150000       4.150000
# 1                       3.0      4.201835          4.150000       4.150000
# 2                       3.0      4.201835          4.150000       4.150000
# 3                       3.0      4.201835          4.150000       4.150000
# 4                       3.0      4.201835          4.150000       4.150000
# ...                     ...           ...               ...            ...
# 518520                  2.0      3.037209          3.100000       4.083333
# 518521                  4.0      5.861171          3.983333       4.083333
# 518522                  2.0      3.037209          3.100000       4.083333
# 518523                  2.0      3.037209          3.100000       4.083333
# 518524                  2.0      3.037209          3.100000       4.083333
#
# [518525 rows x 24 columns]

# %%
tot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 518525 entries, 0 to 518524
# Data columns (total 24 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   origin               518525 non-null  object
#  1   dest                 518525 non-null  object
#  2   date                 518525 non-null  object
#  3   start_time           518525 non-null  int64
#  4   end_time             518525 non-null  int64
#  5   gender               518525 non-null  object
#  6   age                  518525 non-null  int64
#  7   modal                518525 non-null  object
#  8   origin_purpose       518525 non-null  object
#  9   dest_purpose         518525 non-null  object
#  10  od_dist_avg          518525 non-null  float64
#  11  od_duration_avg      518525 non-null  float64
#  12  od_cnts              518525 non-null  int64
#  13  max_time             514580 non-null  float64
#  14  min_time             514580 non-null  float64
#  15  num_transit_methods  514580 non-null  float64
#  16  median_time          514580 non-null  float64
#  17  predict_time         514580 non-null  float64
#  18  max_distance         514580 non-null  float64
#  19  median_distance      514580 non-null  float64
#  20  max_transit_methods  514580 non-null  float64
#  21  num_transfer         514580 non-null  float64
#  22  median_last_walk     514580 non-null  float64
#  23  avg_last_walk        514580 non-null  float64
# dtypes: float64(13), int64(4), object(7)
# memory usage: 94.9+ MB

# %%
tot = tot[['origin', 'dest', 'date', 'start_time', 'end_time', 'gender', 'age', 'modal', 'origin_purpose', 'dest_purpose',
           'od_dist_avg', 'od_duration_avg', 'max_time', 'min_time', 'num_transit_methods', 'median_time', 'predict_time',
           'max_distance', 'median_distance', 'max_transit_methods', 'num_transfer', 'median_last_walk', 'avg_last_walk', 'od_cnts']]
tot
# Out:
#        origin dest      date  start_time  end_time gender  age modal  \
# 0           S    D  20230902          12        16      1    0     0
# 1           S    D  20230902          10        14      0    0     0
# 2           S    D  20230902          10        14      0    0     5
# 3           S    D  20230902          10        13      0    1     0
# 4           S    D  20230902          17        19      0    0     0
# ...       ...  ...       ...         ...       ...    ...  ...   ...
# 518520      G   GB  20231015          12        13      1    2     0
# 518521      S   GB  20231015          13        19      1    2     0
# 518522      G   GB  20231015          20        22      0    2     0
# 518523      G   GB  20231015          14        15      1    7     0
# 518524      G   GB  20231015          21        22      1    2     0
#
#        origin_purpose dest_purpose  ...  num_transit_methods  median_time  \
# 0                 0.0            5  ...                  3.0       9568.0
# 1                 0.0            5  ...                  3.0       9568.0
# 2                 0.0            5  ...                  3.0       9568.0
# 3                 2.0            4  ...                  3.0       9568.0
# 4                 0.0            5  ...                  3.0       9568.0
# ...               ...          ...  ...                  ...          ...
# 518520            4.0            4  ...                  3.0       2155.0
# 518521            5.0            0  ...                  5.0      13121.5
# 518522            4.0            0  ...                  3.0       2155.0
# 518523            5.0            5  ...                  3.0       2155.0
# 518524            5.0            5  ...                  3.0       2155.0
#
#         predict_time  max_distance  median_distance  max_transit_methods  \
# 0         205.338710      154480.0         152219.0                  3.0
# 1         205.338710      154480.0         152219.0                  3.0
# 2         205.338710      154480.0         152219.0                  3.0
# 3         205.338710      154480.0         152219.0                  3.0
# 4         205.338710      154480.0         152219.0                  3.0
# ...              ...           ...              ...                  ...
# 518520    223.325581       31749.0           7296.0                  2.0
# 518521    211.992126      206356.0         182214.0                  4.0
# 518522    223.325581       31749.0           7296.0                  2.0
# 518523    223.325581       31749.0           7296.0                  2.0
# 518524    223.325581       31749.0           7296.0                  2.0
#
#         num_transfer  median_last_walk  avg_last_walk  od_cnts
# 0           4.201835          4.150000       4.150000       21
# 1           4.201835          4.150000       4.150000       27
# 2           4.201835          4.150000       4.150000       27
# 3           4.201835          4.150000       4.150000        9
# 4           4.201835          4.150000       4.150000       27
# ...              ...               ...            ...      ...
# 518520      3.037209          3.100000       4.083333        5
# 518521      5.861171          3.983333       4.083333        5
# 518522      3.037209          3.100000       4.083333        5
# 518523      3.037209          3.100000       4.083333        5
# 518524      3.037209          3.100000       4.083333        5
#
# [518525 rows x 24 columns]

# %%
final_data = tot.loc[np.repeat(tot.index.values, tot.od_cnts)]
final_data = final_data.drop(columns = 'od_cnts')
final_data
# Out:
#        origin dest      date  start_time  end_time gender  age modal  \
# 0           S    D  20230902          12        16      1    0     0
# 0           S    D  20230902          12        16      1    0     0
# 0           S    D  20230902          12        16      1    0     0
# 0           S    D  20230902          12        16      1    0     0
# 0           S    D  20230902          12        16      1    0     0
# ...       ...  ...       ...         ...       ...    ...  ...   ...
# 518524      G   GB  20231015          21        22      1    2     0
# 518524      G   GB  20231015          21        22      1    2     0
# 518524      G   GB  20231015          21        22      1    2     0
# 518524      G   GB  20231015          21        22      1    2     0
# 518524      G   GB  20231015          21        22      1    2     0
#
#        origin_purpose dest_purpose  ...  min_time  num_transit_methods  \
# 0                 0.0            5  ...    6467.0                  3.0
# 0                 0.0            5  ...    6467.0                  3.0
# 0                 0.0            5  ...    6467.0                  3.0
# 0                 0.0            5  ...    6467.0                  3.0
# 0                 0.0            5  ...    6467.0                  3.0
# ...               ...          ...  ...       ...                  ...
# 518524            5.0            5  ...    1844.0                  3.0
# 518524            5.0            5  ...    1844.0                  3.0
# 518524            5.0            5  ...    1844.0                  3.0
# 518524            5.0            5  ...    1844.0                  3.0
# 518524            5.0            5  ...    1844.0                  3.0
#
#         median_time  predict_time  max_distance  median_distance  \
# 0            9568.0    205.338710      154480.0         152219.0
# 0            9568.0    205.338710      154480.0         152219.0
# 0            9568.0    205.338710      154480.0         152219.0
# 0            9568.0    205.338710      154480.0         152219.0
# 0            9568.0    205.338710      154480.0         152219.0
# ...             ...           ...           ...              ...
# 518524       2155.0    223.325581       31749.0           7296.0
# 518524       2155.0    223.325581       31749.0           7296.0
# 518524       2155.0    223.325581       31749.0           7296.0
# 518524       2155.0    223.325581       31749.0           7296.0
# 518524       2155.0    223.325581       31749.0           7296.0
#
#         max_transit_methods  num_transfer  median_last_walk  avg_last_walk
# 0                       3.0      4.201835              4.15       4.150000
# 0                       3.0      4.201835              4.15       4.150000
# 0                       3.0      4.201835              4.15       4.150000
# 0                       3.0      4.201835              4.15       4.150000
# 0                       3.0      4.201835              4.15       4.150000
# ...                     ...           ...               ...            ...
# 518524                  2.0      3.037209              3.10       4.083333
# 518524                  2.0      3.037209              3.10       4.083333
# 518524                  2.0      3.037209              3.10       4.083333
# 518524                  2.0      3.037209              3.10       4.083333
# 518524                  2.0      3.037209              3.10       4.083333
#
# [3968791 rows x 23 columns]

# %%
final_data.to_csv('data/final_data(2).csv')

# %% [markdown]
# ## 파생변수 추가

# %%
final_data = pd.read_csv('data/final_data(2).csv').drop(columns = 'Unnamed: 0')
final_data
# Out:
#         origin dest      date  start_time  end_time  gender  age  modal  \
# 0            S    D  20230902          12        16       1    0      0
# 1            S    D  20230902          12        16       1    0      0
# 2            S    D  20230902          12        16       1    0      0
# 3            S    D  20230902          12        16       1    0      0
# 4            S    D  20230902          12        16       1    0      0
# ...        ...  ...       ...         ...       ...     ...  ...    ...
# 3968786      G   GB  20231015          21        22       1    2      0
# 3968787      G   GB  20231015          21        22       1    2      0
# 3968788      G   GB  20231015          21        22       1    2      0
# 3968789      G   GB  20231015          21        22       1    2      0
# 3968790      G   GB  20231015          21        22       1    2      0
#
#          origin_purpose  dest_purpose  ...  min_time  num_transit_methods  \
# 0                   0.0             5  ...    6467.0                  3.0
# 1                   0.0             5  ...    6467.0                  3.0
# 2                   0.0             5  ...    6467.0                  3.0
# 3                   0.0             5  ...    6467.0                  3.0
# 4                   0.0             5  ...    6467.0                  3.0
# ...                 ...           ...  ...       ...                  ...
# 3968786             5.0             5  ...    1844.0                  3.0
# 3968787             5.0             5  ...    1844.0                  3.0
# 3968788             5.0             5  ...    1844.0                  3.0
# 3968789             5.0             5  ...    1844.0                  3.0
# 3968790             5.0             5  ...    1844.0                  3.0
#
#          median_time  predict_time  max_distance  median_distance  \
# 0             9568.0    205.338710      154480.0         152219.0
# 1             9568.0    205.338710      154480.0         152219.0
# 2             9568.0    205.338710      154480.0         152219.0
# 3             9568.0    205.338710      154480.0         152219.0
# 4             9568.0    205.338710      154480.0         152219.0
# ...              ...           ...           ...              ...
# 3968786       2155.0    223.325581       31749.0           7296.0
# 3968787       2155.0    223.325581       31749.0           7296.0
# 3968788       2155.0    223.325581       31749.0           7296.0
# 3968789       2155.0    223.325581       31749.0           7296.0
# 3968790       2155.0    223.325581       31749.0           7296.0
#
#          max_transit_methods  num_transfer  median_last_walk  avg_last_walk
# 0                        3.0      4.201835              4.15       4.150000
# 1                        3.0      4.201835              4.15       4.150000
# 2                        3.0      4.201835              4.15       4.150000
# 3                        3.0      4.201835              4.15       4.150000
# 4                        3.0      4.201835              4.15       4.150000
# ...                      ...           ...               ...            ...
# 3968786                  2.0      3.037209              3.10       4.083333
# 3968787                  2.0      3.037209              3.10       4.083333
# 3968788                  2.0      3.037209              3.10       4.083333
# 3968789                  2.0      3.037209              3.10       4.083333
# 3968790                  2.0      3.037209              3.10       4.083333
#
# [3968791 rows x 23 columns]

# %%
final_data.date = final_data.date.astype('str')

# %% [markdown]
# ### isFestival

# %%
def add_isFestival(df, origin, dest, f_dates):
  filtered_df = df[(df.origin == origin)&(df.dest == dest)]
  date_to_festival = {}
  filtered_df.date = filtered_df.date.astype('string')
  unique_dates = final_data.date.unique()
  for date in unique_dates:
    date_obj = datetime.strptime(date, '%Y%m%d')
    if date in f_dates:
      date_to_festival[date] = True
    else:
      date_to_festival[date] = False
  filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
  return filtered_df

# %% [markdown]
# #### 대전

# %%
d_dates = ['20230908', '20230909', '20230910']


# 서울 -> 대전
sd = add_isFestival(final_data, 'S', 'D', d_dates)

# 부산 -> 대전
bd = add_isFestival(final_data, 'B', 'D', d_dates)

# 대전 -> 대전
dd = add_isFestival(final_data, 'D', 'D', d_dates)

# 강릉 -> 대전
gd = add_isFestival(final_data, 'G', 'D', d_dates)

# 임실 -> 대전
id = add_isFestival(final_data, 'I', 'D', d_dates)

d = pd.concat([sd, bd, dd, gd, id])
d
# Out:
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
#         origin dest      date  start_time  end_time  gender  age  modal  \
# 0            S    D  20230902          12        16       1    0      0
# 1            S    D  20230902          12        16       1    0      0
# 2            S    D  20230902          12        16       1    0      0
# 3            S    D  20230902          12        16       1    0      0
# 4            S    D  20230902          12        16       1    0      0
# ...        ...  ...       ...         ...       ...     ...  ...    ...
# 1772164      I    D  20231015          19        20       1    4      0
# 1772165      I    D  20231015          19        20       1    4      0
# 1772166      I    D  20231015          19        20       1    4      0
# 1772167      I    D  20231015          19        20       1    4      0
# 1772168      I    D  20231015          19        20       1    4      0
#
#          origin_purpose  dest_purpose  ...  num_transit_methods  median_time  \
# 0                   0.0             5  ...                  3.0       9568.0
# 1                   0.0             5  ...                  3.0       9568.0
# 2                   0.0             5  ...                  3.0       9568.0
# 3                   0.0             5  ...                  3.0       9568.0
# 4                   0.0             5  ...                  3.0       9568.0
# ...                 ...           ...  ...                  ...          ...
# 1772164             3.0             0  ...                  NaN          NaN
# 1772165             3.0             0  ...                  NaN          NaN
# 1772166             3.0             0  ...                  NaN          NaN
# 1772167             3.0             0  ...                  NaN          NaN
# 1772168             3.0             0  ...                  NaN          NaN
#
#          predict_time  max_distance  median_distance  max_transit_methods  \
# 0           205.33871      154480.0         152219.0                  3.0
# 1           205.33871      154480.0         152219.0                  3.0
# 2           205.33871      154480.0         152219.0                  3.0
# 3           205.33871      154480.0         152219.0                  3.0
# 4           205.33871      154480.0         152219.0                  3.0
# ...               ...           ...              ...                  ...
# 1772164           NaN           NaN              NaN                  NaN
# 1772165           NaN           NaN              NaN                  NaN
# 1772166           NaN           NaN              NaN                  NaN
# 1772167           NaN           NaN              NaN                  NaN
# 1772168           NaN           NaN              NaN                  NaN
#
#          num_transfer  median_last_walk  avg_last_walk  isFestival
# 0            4.201835              4.15           4.15       False
# 1            4.201835              4.15           4.15       False
# 2            4.201835              4.15           4.15       False
# 3            4.201835              4.15           4.15       False
# 4            4.201835              4.15           4.15       False
# ...               ...               ...            ...         ...
# 1772164           NaN               NaN            NaN       False
# 1772165           NaN               NaN            NaN       False
# 1772166           NaN               NaN            NaN       False
# 1772167           NaN               NaN            NaN       False
# 1772168           NaN               NaN            NaN       False
#
# [803014 rows x 24 columns]

# %%
d.value_counts('isFestival')
# Out:
# isFestival
# False    714596
# True      75904
# Name: count, dtype: int64

# %% [markdown]
# #### 부산

# %%
b_dates = ['20231004', '20231005', '20231006', '20231007', '20231008', '20231009', '20231010', '20231011', '20231012', '20231013']

# 서울 -> 부산
sb = add_isFestival(final_data, 'S', 'B', b_dates)

# 부산 -> 부산
bb = add_isFestival(final_data, 'B', 'B', b_dates)

# 강릉 -> 부산
gb = add_isFestival(final_data, 'G', 'B', b_dates)

# 대전 -> 부산
db = add_isFestival(final_data, 'D', 'B', b_dates)

# 임실 -> 부산
ib = add_isFestival(final_data, 'I', 'B', b_dates)

b = pd.concat([sb, bb, gb, db, ib])
b
# Out:
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
#         origin dest      date  start_time  end_time  gender  age  modal  \
# 229274       S    B  20230908          19        22       0    3      7
# 229275       S    B  20230908          19        22       0    3      7
# 229276       S    B  20230908          19        22       0    3      7
# 229277       S    B  20230908          19        22       0    3      7
# 229278       S    B  20230908          19        22       0    3      7
# ...        ...  ...       ...         ...       ...     ...  ...    ...
# 2899614      I    B  20231015          15        19       0    2      0
# 2899615      I    B  20231015          15        19       0    2      0
# 2899616      I    B  20231015          15        19       0    2      0
# 2899617      I    B  20231015          15        19       0    2      0
# 2899618      I    B  20231015          15        19       0    2      0
#
#          origin_purpose  dest_purpose  ...  num_transit_methods  median_time  \
# 229274              4.0             5  ...                  4.0      20332.0
# 229275              4.0             5  ...                  4.0      20332.0
# 229276              4.0             5  ...                  4.0      20332.0
# 229277              4.0             5  ...                  4.0      20332.0
# 229278              4.0             5  ...                  4.0      20332.0
# ...                 ...           ...  ...                  ...          ...
# 2899614             5.0             0  ...                  NaN          NaN
# 2899615             5.0             0  ...                  NaN          NaN
# 2899616             5.0             0  ...                  NaN          NaN
# 2899617             5.0             0  ...                  NaN          NaN
# 2899618             5.0             0  ...                  NaN          NaN
#
#          predict_time  max_distance  median_distance  max_transit_methods  \
# 229274     276.149733      369479.0         340841.0                  4.0
# 229275     276.149733      369479.0         340841.0                  4.0
# 229276     276.149733      369479.0         340841.0                  4.0
# 229277     276.149733      369479.0         340841.0                  4.0
# 229278     276.149733      369479.0         340841.0                  4.0
# ...               ...           ...              ...                  ...
# 2899614           NaN           NaN              NaN                  NaN
# 2899615           NaN           NaN              NaN                  NaN
# 2899616           NaN           NaN              NaN                  NaN
# 2899617           NaN           NaN              NaN                  NaN
# 2899618           NaN           NaN              NaN                  NaN
#
#          num_transfer  median_last_walk  avg_last_walk  isFestival
# 229274       4.082317              5.05      10.066667       False
# 229275       4.082317              5.05      10.066667       False
# 229276       4.082317              5.05      10.066667       False
# 229277       4.082317              5.05      10.066667       False
# 229278       4.082317              5.05      10.066667       False
# ...               ...               ...            ...         ...
# 2899614           NaN               NaN            NaN       False
# 2899615           NaN               NaN            NaN       False
# 2899616           NaN               NaN            NaN       False
# 2899617           NaN               NaN            NaN       False
# 2899618           NaN               NaN            NaN       False
#
# [1231785 rows x 24 columns]

# %%
b.value_counts('isFestival')
# Out:
# isFestival
# False    938677
# True     291314
# Name: count, dtype: int64

# %% [markdown]
# #### 임실

# %%
i_dates = ['20231006', '20231007', '20231008', '20231009']

# 서울 -> 임실
si = add_isFestival(final_data, 'S', 'I', i_dates)

# 부산 -> 임실
bi = add_isFestival(final_data, 'B', 'I', i_dates)

# 전북 -> 임실
ii = add_isFestival(final_data, 'I', 'I', i_dates)

# 대전 -> 임실
di = add_isFestival(final_data, 'D', 'I', i_dates)

i = pd.concat([si, bi, ii, di])
i
# Out:
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
#         origin dest      date  start_time  end_time  gender  age  modal  \
# 319941       S    I  20230901          17        23       0    3      0
# 319942       S    I  20230901          17        23       0    3      0
# 319943       S    I  20230901          17        23       0    3      0
# 319944       S    I  20230901          17        23       0    3      0
# 319945       S    I  20230901          17        23       0    3      0
# ...        ...  ...       ...         ...       ...     ...  ...    ...
# 2949902      D    I  20231015          14        17       0    0      0
# 2949903      D    I  20231015          14        17       0    0      0
# 2949904      D    I  20231015          14        17       0    0      0
# 2949905      D    I  20231015          14        17       0    0      0
# 2949906      D    I  20231015          14        17       0    0      0
#
#          origin_purpose  dest_purpose  ...  num_transit_methods  median_time  \
# 319941              4.0             5  ...                  4.0      14428.0
# 319942              4.0             5  ...                  4.0      14428.0
# 319943              4.0             5  ...                  4.0      14428.0
# 319944              4.0             5  ...                  4.0      14428.0
# 319945              4.0             5  ...                  4.0      14428.0
# ...                 ...           ...  ...                  ...          ...
# 2949902             5.0             0  ...                  NaN          NaN
# 2949903             5.0             0  ...                  NaN          NaN
# 2949904             5.0             0  ...                  NaN          NaN
# 2949905             5.0             0  ...                  NaN          NaN
# 2949906             5.0             0  ...                  NaN          NaN
#
#          predict_time  max_distance  median_distance  max_transit_methods  \
# 319941     481.507433      226695.0         221938.0                  3.0
# 319942     481.507433      226695.0         221938.0                  3.0
# 319943     481.507433      226695.0         221938.0                  3.0
# 319944     481.507433      226695.0         221938.0                  3.0
# 319945     481.507433      226695.0         221938.0                  3.0
# ...               ...           ...              ...                  ...
# 2949902           NaN           NaN              NaN                  NaN
# 2949903           NaN           NaN              NaN                  NaN
# 2949904           NaN           NaN              NaN                  NaN
# 2949905           NaN           NaN              NaN                  NaN
# 2949906           NaN           NaN              NaN                  NaN
#
#          num_transfer  median_last_walk  avg_last_walk  isFestival
# 319941       3.318584          4.383333       7.883333       False
# 319942       3.318584          4.383333       7.883333       False
# 319943       3.318584          4.383333       7.883333       False
# 319944       3.318584          4.383333       7.883333       False
# 319945       3.318584          4.383333       7.883333       False
# ...               ...               ...            ...         ...
# 2949902           NaN               NaN            NaN       False
# 2949903           NaN               NaN            NaN       False
# 2949904           NaN               NaN            NaN       False
# 2949905           NaN               NaN            NaN       False
# 2949906           NaN               NaN            NaN       False
#
# [64678 rows x 24 columns]

# %%
i.value_counts('isFestival')
# Out:
# isFestival
# True     34113
# False    30070
# Name: count, dtype: int64

# %% [markdown]
# #### 서울

# %%
s_dates = ['20231007']

# 서울 -> 서울
ss = add_isFestival(final_data, 'S', 'S', s_dates)

# 부산 -> 서울
bs = add_isFestival(final_data, 'B', 'S', s_dates)

# 임실 -> 서울
iis = add_isFestival(final_data, 'I', 'S', s_dates)

# 강릉 -> 서울
gs = add_isFestival(final_data, 'G', 'S', s_dates)

# 대전 -> 서울
ds = add_isFestival(final_data, 'D', 'S', s_dates)

s = pd.concat([ss, bs, iis, gs, ds])
s
# Out:
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
#         origin dest      date  start_time  end_time  gender  age  modal  \
# 347701       S    S  20230901          16        17       1    3      2
# 347702       S    S  20230901          16        17       1    3      2
# 347703       S    S  20230901          16        17       1    3      2
# 347704       S    S  20230901          16        17       1    3      2
# 347705       S    S  20230901          16        17       1    3      2
# ...        ...  ...       ...         ...       ...     ...  ...    ...
# 3653501      D    S  20231015          16        19       1    2      0
# 3653502      D    S  20231015          16        19       1    2      0
# 3653503      D    S  20231015          16        19       1    2      0
# 3653504      D    S  20231015          16        19       1    2      0
# 3653505      D    S  20231015          16        19       1    2      0
#
#          origin_purpose  dest_purpose  ...  num_transit_methods  median_time  \
# 347701              1.0             3  ...                  2.0       1717.0
# 347702              1.0             3  ...                  2.0       1717.0
# 347703              1.0             3  ...                  2.0       1717.0
# 347704              1.0             3  ...                  2.0       1717.0
# 347705              1.0             3  ...                  2.0       1717.0
# ...                 ...           ...  ...                  ...          ...
# 3653501             3.0             0  ...                  NaN          NaN
# 3653502             3.0             0  ...                  NaN          NaN
# 3653503             3.0             0  ...                  NaN          NaN
# 3653504             3.0             0  ...                  NaN          NaN
# 3653505             3.0             0  ...                  NaN          NaN
#
#          predict_time  max_distance  median_distance  max_transit_methods  \
# 347701     199.423729       10875.0           6775.0                  2.0
# 347702     199.423729       10875.0           6775.0                  2.0
# 347703     199.423729       10875.0           6775.0                  2.0
# 347704     199.423729       10875.0           6775.0                  2.0
# 347705     199.423729       10875.0           6775.0                  2.0
# ...               ...           ...              ...                  ...
# 3653501           NaN           NaN              NaN                  NaN
# 3653502           NaN           NaN              NaN                  NaN
# 3653503           NaN           NaN              NaN                  NaN
# 3653504           NaN           NaN              NaN                  NaN
# 3653505           NaN           NaN              NaN                  NaN
#
#          num_transfer  median_last_walk  avg_last_walk  isFestival
# 347701       2.969388              3.65           5.15       False
# 347702       2.969388              3.65           5.15       False
# 347703       2.969388              3.65           5.15       False
# 347704       2.969388              3.65           5.15       False
# 347705       2.969388              3.65           5.15       False
# ...               ...               ...            ...         ...
# 3653501           NaN               NaN            NaN       False
# 3653502           NaN               NaN            NaN       False
# 3653503           NaN               NaN            NaN       False
# 3653504           NaN               NaN            NaN       False
# 3653505           NaN               NaN            NaN       False
#
# [1048896 rows x 24 columns]

# %% [markdown]
# #### 강릉(1)

# %%
g_dates = ['20231012', '20231013', '20231014', '20231015']

# 서울 -> 강릉(1)
sga = add_isFestival(final_data, 'S', 'GA', g_dates)

# 부산 -> 강릉(1)
bga = add_isFestival(final_data, 'B', 'GA', g_dates)

# 강릉 -> 강릉(1)
gga = add_isFestival(final_data, 'G', 'GA', g_dates)

# 임실 -> 강릉(1)
iga = add_isFestival(final_data, 'I', 'GA', g_dates)

# 대전 -> 강릉(1)
dga = add_isFestival(final_data, 'D', 'GA', g_dates)

ga = pd.concat([sga, bga, gga, iga, dga])
ga
# Out:
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
#         origin dest      date  start_time  end_time  gender  age  modal  \
# 693608       S   GA  20230901          15        19       0    0      0
# 693609       S   GA  20230901          15        19       0    0      0
# 693610       S   GA  20230901          15        19       0    0      0
# 693611       S   GA  20230901          15        19       0    0      0
# 693612       S   GA  20230901          15        19       0    0      0
# ...        ...  ...       ...         ...       ...     ...  ...    ...
# 3725039      D   GA  20231010          12        16       0    3      0
# 3725040      D   GA  20231010          12        16       0    3      0
# 3725041      D   GA  20231010          12        16       0    3      0
# 3725042      D   GA  20231010          12        16       0    3      0
# 3725043      D   GA  20231010          12        16       0    3      0
#
#          origin_purpose  dest_purpose  ...  num_transit_methods  median_time  \
# 693608              0.0             5  ...                  3.0      11640.0
# 693609              0.0             5  ...                  3.0      11640.0
# 693610              0.0             5  ...                  3.0      11640.0
# 693611              0.0             5  ...                  3.0      11640.0
# 693612              0.0             5  ...                  3.0      11640.0
# ...                 ...           ...  ...                  ...          ...
# 3725039             5.0             0  ...                  NaN          NaN
# 3725040             5.0             0  ...                  NaN          NaN
# 3725041             5.0             0  ...                  NaN          NaN
# 3725042             5.0             0  ...                  NaN          NaN
# 3725043             5.0             0  ...                  NaN          NaN
#
#          predict_time  max_distance  median_distance  max_transit_methods  \
# 693608     696.526316      220586.0         204386.0                  3.0
# 693609     696.526316      220586.0         204386.0                  3.0
# 693610     696.526316      220586.0         204386.0                  3.0
# 693611     696.526316      220586.0         204386.0                  3.0
# 693612     696.526316      220586.0         204386.0                  3.0
# ...               ...           ...              ...                  ...
# 3725039           NaN           NaN              NaN                  NaN
# 3725040           NaN           NaN              NaN                  NaN
# 3725041           NaN           NaN              NaN                  NaN
# 3725042           NaN           NaN              NaN                  NaN
# 3725043           NaN           NaN              NaN                  NaN
#
#          num_transfer  median_last_walk  avg_last_walk  isFestival
# 693608       3.305556               4.0           29.0       False
# 693609       3.305556               4.0           29.0       False
# 693610       3.305556               4.0           29.0       False
# 693611       3.305556               4.0           29.0       False
# 693612       3.305556               4.0           29.0       False
# ...               ...               ...            ...         ...
# 3725039           NaN               NaN            NaN       False
# 3725040           NaN               NaN            NaN       False
# 3725041           NaN               NaN            NaN       False
# 3725042           NaN               NaN            NaN       False
# 3725043           NaN               NaN            NaN       False
#
# [364842 rows x 24 columns]

# %% [markdown]
# #### 강릉(2)

# %%
g_dates = ['20231012', '20231013', '20231014', '20231015']

# 서울 -> 강릉(2)
sgb = add_isFestival(final_data, 'S', 'GB', g_dates)

# 부산 -> 강릉(2)
bgb = add_isFestival(final_data, 'B', 'GB', g_dates)

# 강릉 -> 강릉(2)
ggb = add_isFestival(final_data, 'G', 'GB', g_dates)

# 대전 -> 강릉(2)
dgb = add_isFestival(final_data, 'D', 'GB', g_dates)

# 임실 -> 강릉(2)
igb = add_isFestival(final_data, 'I', 'GB', g_dates)

gb = pd.concat([sgb, bgb, ggb, dgb, igb])
gb
# Out:
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
# <ipython-input-20-d62ac0a9a2ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.date = filtered_df.date.astype('string')
# <ipython-input-20-d62ac0a9a2ee>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['isFestival'] = filtered_df['date'].map(date_to_festival)
#         origin dest      date  start_time  end_time  gender  age  modal  \
# 975155       S   GB  20230901          17        21       1    3      0
# 975156       S   GB  20230901          17        21       1    3      0
# 975157       S   GB  20230901          17        21       1    3      0
# 975158       S   GB  20230901          17        21       1    3      0
# 975159       S   GB  20230901          17        21       1    3      0
# ...        ...  ...       ...         ...       ...     ...  ...    ...
# 3962710      I   GB  20231014          12        18       1    1      0
# 3962711      I   GB  20231014          12        18       1    1      0
# 3962712      I   GB  20231014          12        18       1    1      0
# 3962713      I   GB  20231014          12        18       1    1      0
# 3962714      I   GB  20231014          12        18       1    1      0
#
#          origin_purpose  dest_purpose  ...  num_transit_methods  median_time  \
# 975155              4.0             5  ...                  5.0      13121.5
# 975156              4.0             5  ...                  5.0      13121.5
# 975157              4.0             5  ...                  5.0      13121.5
# 975158              4.0             5  ...                  5.0      13121.5
# 975159              4.0             5  ...                  5.0      13121.5
# ...                 ...           ...  ...                  ...          ...
# 3962710             5.0             0  ...                  NaN          NaN
# 3962711             5.0             0  ...                  NaN          NaN
# 3962712             5.0             0  ...                  NaN          NaN
# 3962713             5.0             0  ...                  NaN          NaN
# 3962714             5.0             0  ...                  NaN          NaN
#
#          predict_time  max_distance  median_distance  max_transit_methods  \
# 975155     211.992126      206356.0         182214.0                  4.0
# 975156     211.992126      206356.0         182214.0                  4.0
# 975157     211.992126      206356.0         182214.0                  4.0
# 975158     211.992126      206356.0         182214.0                  4.0
# 975159     211.992126      206356.0         182214.0                  4.0
# ...               ...           ...              ...                  ...
# 3962710           NaN           NaN              NaN                  NaN
# 3962711           NaN           NaN              NaN                  NaN
# 3962712           NaN           NaN              NaN                  NaN
# 3962713           NaN           NaN              NaN                  NaN
# 3962714           NaN           NaN              NaN                  NaN
#
#          num_transfer  median_last_walk  avg_last_walk  isFestival
# 975155       5.861171          3.983333       4.083333       False
# 975156       5.861171          3.983333       4.083333       False
# 975157       5.861171          3.983333       4.083333       False
# 975158       5.861171          3.983333       4.083333       False
# 975159       5.861171          3.983333       4.083333       False
# ...               ...               ...            ...         ...
# 3962710           NaN               NaN            NaN        True
# 3962711           NaN               NaN            NaN        True
# 3962712           NaN               NaN            NaN        True
# 3962713           NaN               NaN            NaN        True
# 3962714           NaN               NaN            NaN        True
#
# [455576 rows x 24 columns]

# %%
final_data = pd.concat([d, b, i, s, ga, gb])
final_data
# Out:
#         origin dest      date  start_time  end_time  gender  age  modal  \
# 0            S    D  20230902          12        16       1    0      0
# 1            S    D  20230902          12        16       1    0      0
# 2            S    D  20230902          12        16       1    0      0
# 3            S    D  20230902          12        16       1    0      0
# 4            S    D  20230902          12        16       1    0      0
# ...        ...  ...       ...         ...       ...     ...  ...    ...
# 3962710      I   GB  20231014          12        18       1    1      0
# 3962711      I   GB  20231014          12        18       1    1      0
# 3962712      I   GB  20231014          12        18       1    1      0
# 3962713      I   GB  20231014          12        18       1    1      0
# 3962714      I   GB  20231014          12        18       1    1      0
#
#          origin_purpose  dest_purpose  ...  num_transit_methods  median_time  \
# 0                   0.0             5  ...                  3.0       9568.0
# 1                   0.0             5  ...                  3.0       9568.0
# 2                   0.0             5  ...                  3.0       9568.0
# 3                   0.0             5  ...                  3.0       9568.0
# 4                   0.0             5  ...                  3.0       9568.0
# ...                 ...           ...  ...                  ...          ...
# 3962710             5.0             0  ...                  NaN          NaN
# 3962711             5.0             0  ...                  NaN          NaN
# 3962712             5.0             0  ...                  NaN          NaN
# 3962713             5.0             0  ...                  NaN          NaN
# 3962714             5.0             0  ...                  NaN          NaN
#
#          predict_time  max_distance  median_distance  max_transit_methods  \
# 0           205.33871      154480.0         152219.0                  3.0
# 1           205.33871      154480.0         152219.0                  3.0
# 2           205.33871      154480.0         152219.0                  3.0
# 3           205.33871      154480.0         152219.0                  3.0
# 4           205.33871      154480.0         152219.0                  3.0
# ...               ...           ...              ...                  ...
# 3962710           NaN           NaN              NaN                  NaN
# 3962711           NaN           NaN              NaN                  NaN
# 3962712           NaN           NaN              NaN                  NaN
# 3962713           NaN           NaN              NaN                  NaN
# 3962714           NaN           NaN              NaN                  NaN
#
#          num_transfer  median_last_walk  avg_last_walk  isFestival
# 0            4.201835              4.15           4.15       False
# 1            4.201835              4.15           4.15       False
# 2            4.201835              4.15           4.15       False
# 3            4.201835              4.15           4.15       False
# 4            4.201835              4.15           4.15       False
# ...               ...               ...            ...         ...
# 3962710           NaN               NaN            NaN        True
# 3962711           NaN               NaN            NaN        True
# 3962712           NaN               NaN            NaN        True
# 3962713           NaN               NaN            NaN        True
# 3962714           NaN               NaN            NaN        True
#
# [3968791 rows x 24 columns]

# %%
final_data.value_counts('isFestival')
# Out:
# isFestival
# False    3363014
# True      605777
# Name: count, dtype: int64

# %% [markdown]
# ### isWeekend

# %%
def add_isWeekend(filtered_df):
  filtered_df.date = filtered_df.date.astype('string')
  unique_dates = filtered_df.date.unique()
  date_to_weekend = {}
  for date in unique_dates:
    date_obj = datetime.strptime(date, '%Y%m%d')
    date_to_weekend[date] = date_obj.weekday() >= 5
  filtered_df['isWeekend'] = filtered_df['date'].map(date_to_weekend)
  return filtered_df

# %%
final_data = add_isWeekend(final_data)
final_data
# Out:
#         origin dest      date  start_time  end_time  gender  age  modal  \
# 0            S    D  20230902          12        16       1    0      0
# 1            S    D  20230902          12        16       1    0      0
# 2            S    D  20230902          12        16       1    0      0
# 3            S    D  20230902          12        16       1    0      0
# 4            S    D  20230902          12        16       1    0      0
# ...        ...  ...       ...         ...       ...     ...  ...    ...
# 3962710      I   GB  20231014          12        18       1    1      0
# 3962711      I   GB  20231014          12        18       1    1      0
# 3962712      I   GB  20231014          12        18       1    1      0
# 3962713      I   GB  20231014          12        18       1    1      0
# 3962714      I   GB  20231014          12        18       1    1      0
#
#          origin_purpose  dest_purpose  ...  median_time  predict_time  \
# 0                   0.0             5  ...       9568.0     205.33871
# 1                   0.0             5  ...       9568.0     205.33871
# 2                   0.0             5  ...       9568.0     205.33871
# 3                   0.0             5  ...       9568.0     205.33871
# 4                   0.0             5  ...       9568.0     205.33871
# ...                 ...           ...  ...          ...           ...
# 3962710             5.0             0  ...          NaN           NaN
# 3962711             5.0             0  ...          NaN           NaN
# 3962712             5.0             0  ...          NaN           NaN
# 3962713             5.0             0  ...          NaN           NaN
# 3962714             5.0             0  ...          NaN           NaN
#
#          max_distance  median_distance  max_transit_methods  num_transfer  \
# 0            154480.0         152219.0                  3.0      4.201835
# 1            154480.0         152219.0                  3.0      4.201835
# 2            154480.0         152219.0                  3.0      4.201835
# 3            154480.0         152219.0                  3.0      4.201835
# 4            154480.0         152219.0                  3.0      4.201835
# ...               ...              ...                  ...           ...
# 3962710           NaN              NaN                  NaN           NaN
# 3962711           NaN              NaN                  NaN           NaN
# 3962712           NaN              NaN                  NaN           NaN
# 3962713           NaN              NaN                  NaN           NaN
# 3962714           NaN              NaN                  NaN           NaN
#
#          median_last_walk  avg_last_walk  isFestival  isWeekend
# 0                    4.15           4.15       False       True
# 1                    4.15           4.15       False       True
# 2                    4.15           4.15       False       True
# 3                    4.15           4.15       False       True
# 4                    4.15           4.15       False       True
# ...                   ...            ...         ...        ...
# 3962710               NaN            NaN        True       True
# 3962711               NaN            NaN        True       True
# 3962712               NaN            NaN        True       True
# 3962713               NaN            NaN        True       True
# 3962714               NaN            NaN        True       True
#
# [3968791 rows x 25 columns]

# %%
final_data.value_counts('isWeekend')
# Out:
# isWeekend
# False    2115100
# True     1853691
# Name: count, dtype: int64

# %%
final_data = final_data.dropna(how = 'any', subset = ['max_time', 'min_time'])
final_data
# Out:
#         origin dest      date  start_time  end_time  gender  age  modal  \
# 0            S    D  20230902          12        16       1    0      0
# 1            S    D  20230902          12        16       1    0      0
# 2            S    D  20230902          12        16       1    0      0
# 3            S    D  20230902          12        16       1    0      0
# 4            S    D  20230902          12        16       1    0      0
# ...        ...  ...       ...         ...       ...     ...  ...    ...
# 3968786      G   GB  20231015          21        22       1    2      0
# 3968787      G   GB  20231015          21        22       1    2      0
# 3968788      G   GB  20231015          21        22       1    2      0
# 3968789      G   GB  20231015          21        22       1    2      0
# 3968790      G   GB  20231015          21        22       1    2      0
#
#          origin_purpose  dest_purpose  ...  median_time  predict_time  \
# 0                   0.0             5  ...       9568.0    205.338710
# 1                   0.0             5  ...       9568.0    205.338710
# 2                   0.0             5  ...       9568.0    205.338710
# 3                   0.0             5  ...       9568.0    205.338710
# 4                   0.0             5  ...       9568.0    205.338710
# ...                 ...           ...  ...          ...           ...
# 3968786             5.0             5  ...       2155.0    223.325581
# 3968787             5.0             5  ...       2155.0    223.325581
# 3968788             5.0             5  ...       2155.0    223.325581
# 3968789             5.0             5  ...       2155.0    223.325581
# 3968790             5.0             5  ...       2155.0    223.325581
#
#          max_distance  median_distance  max_transit_methods  num_transfer  \
# 0            154480.0         152219.0                  3.0      4.201835
# 1            154480.0         152219.0                  3.0      4.201835
# 2            154480.0         152219.0                  3.0      4.201835
# 3            154480.0         152219.0                  3.0      4.201835
# 4            154480.0         152219.0                  3.0      4.201835
# ...               ...              ...                  ...           ...
# 3968786       31749.0           7296.0                  2.0      3.037209
# 3968787       31749.0           7296.0                  2.0      3.037209
# 3968788       31749.0           7296.0                  2.0      3.037209
# 3968789       31749.0           7296.0                  2.0      3.037209
# 3968790       31749.0           7296.0                  2.0      3.037209
#
#          median_last_walk  avg_last_walk  isFestival  isWeekend
# 0                    4.15       4.150000       False       True
# 1                    4.15       4.150000       False       True
# 2                    4.15       4.150000       False       True
# 3                    4.15       4.150000       False       True
# 4                    4.15       4.150000       False       True
# ...                   ...            ...         ...        ...
# 3968786              3.10       4.083333        True       True
# 3968787              3.10       4.083333        True       True
# 3968788              3.10       4.083333        True       True
# 3968789              3.10       4.083333        True       True
# 3968790              3.10       4.083333        True       True
#
# [3940993 rows x 25 columns]

# %%
final_data.value_counts('isWeekend')
# Out:
# isWeekend
# False    2100867
# True     1840126
# Name: count, dtype: int64

# %%
final_data.to_csv('data/final_model_data.csv')
