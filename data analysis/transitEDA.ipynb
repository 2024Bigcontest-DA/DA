# %% [markdown]
# ## 구글 드라이브 마운트

# %%
from google.colab import drive
import os

drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/BigContest')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 라이브러리

# %%
import dask.dataframe as dd
import time
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## 데이터 불러오기

# %%
transit = pd.read_csv('data/transit.csv')
transit
# Out:
#      routeID  transitID            transit description    time
# 0       SD01          1               WALK           -   303.0
# 1       SD01          2            TRAIN_1       KTX산천  4215.0
# 2       SD01          3               WALK           -   254.0
# 3       SD01          4                BUS      일반:707  1974.0
# 4       SD01          5               WALK           -   249.0
# ...      ...        ...                ...         ...     ...
# 5820    II10          4              BUS_2  농어촌:임실-신흥촌   185.0
# 5821    II10          5               WALK           -   473.0
# 5822    II10         99      totalDistance           -  2991.0
# 5823    II10         99          totalTime           -   990.0
# 5824    II10         99  totalWalkDistance           -   523.0
#
# [5825 rows x 5 columns]

# %%
transit['origin_cd'] = transit.routeID.str[0]
transit['dest_cd'] = transit.routeID.apply(lambda x: x[1:3] if len(x) == 5 else x[1])
transit
# Out:
#      routeID  transitID            transit description    time origin_cd  \
# 0       SD01          1               WALK           -   303.0         S
# 1       SD01          2            TRAIN_1       KTX산천  4215.0         S
# 2       SD01          3               WALK           -   254.0         S
# 3       SD01          4                BUS      일반:707  1974.0         S
# 4       SD01          5               WALK           -   249.0         S
# ...      ...        ...                ...         ...     ...       ...
# 5820    II10          4              BUS_2  농어촌:임실-신흥촌   185.0         I
# 5821    II10          5               WALK           -   473.0         I
# 5822    II10         99      totalDistance           -  2991.0         I
# 5823    II10         99          totalTime           -   990.0         I
# 5824    II10         99  totalWalkDistance           -   523.0         I
#
#      dest_cd
# 0          D
# 1          D
# 2          D
# 3          D
# 4          D
# ...      ...
# 5820       I
# 5821       I
# 5822       I
# 5823       I
# 5824       I
#
# [5825 rows x 7 columns]

# %%
cd = {'S': '서울',
      'B': '부산',
      'D': '대전',
      'GA': '강릉(스피드 스케이트 경기장)',
      'GB': '강릉(경포호수광장)',
      'I': '임실',
      }
transit.origin_cd = transit.origin_cd.map(cd)
transit.dest_cd = transit.dest_cd.map(cd)

# %%
df
# Out:
#     routeID       time
# 0      BB01  56.150000
# 1      BB02  47.350000
# 2      BB03  47.350000
# 3      BB04  49.716667
# 4      BB05  48.900000
# ..      ...        ...
# 464    SS16  28.766667
# 465    SS17  28.766667
# 466    SS18  42.966667
# 467    SS19  42.966667
# 468    SS20  41.916667
#
# [469 rows x 2 columns]

# %%
transit.transit = transit.transit.apply(lambda x: x.split('_')[0])

# %% [markdown]
# ## EDA

# %%
transit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5825 entries, 0 to 5824
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   routeID      5825 non-null   object
#  1   transitID    5825 non-null   int64
#  2   transit      5825 non-null   object
#  3   description  5798 non-null   object
#  4   time         5821 non-null   float64
#  5   origin_cd    5197 non-null   object
#  6   dest_cd      5825 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 318.7+ KB

# %% [markdown]
# ### 도보(환승) 접근성

# %% [markdown]
# #### (전체) 도보시간 합계 분포

# %%
import plotly.express as px
df = transit[transit.transit == 'WALK'].groupby('routeID').time.sum().reset_index()
df.time = df.time / 60
fig = px.box(df,y="time", title = '(전체) 도보시간 합계 분포 (단위: 분)')
fig.update_yaxes(tickformat=',')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0ff5843a-31c3-42a2-9030-9a735eec9629" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ff5843a-31c3-42a2-9030-9a735eec9629")) {                    Plotly.newPlot(                        "0ff5843a-31c3-42a2-9030-9a735eec9629",                        [{"alignmentgroup":"True","hovertemplate":"time=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[11.216666666666667,14.233333333333333,14.233333333333333,14.516666666666667,13.616666666666667,13.616666666666667,13.616666666666667,11.3,13.183333333333334,14.533333333333333,15.75,15.333333333333334,15.333333333333334,15.333333333333334,15.333333333333334,12.933333333333334,12.933333333333334,12.933333333333334,12.933333333333334,12.933333333333334,14.083333333333334,14.083333333333334,14.083333333333334,14.083333333333334,14.083333333333334,14.083333333333334,14.083333333333334,14.083333333333334,14.083333333333334,14.083333333333334,12.983333333333333,12.983333333333333,12.983333333333333,12.983333333333333,12.983333333333333,14.983333333333333,14.983333333333333,14.983333333333333,14.983333333333333,14.983333333333333,14.983333333333333,14.983333333333333,14.983333333333333,14.983333333333333,14.983333333333333,14.983333333333333,14.983333333333333,14.983333333333333,14.983333333333333,14.983333333333333,12.216666666666667,12.216666666666667,12.216666666666667,12.216666666666667,12.216666666666667,13.45,13.45,13.45,13.45,13.45,13.866666666666667,13.866666666666667,13.866666666666667,13.866666666666667,13.866666666666667,14.4,14.4,14.4,14.4,14.4,14.4,14.4,14.4,14.4,14.4,13.166666666666666,13.166666666666666,13.166666666666666,13.166666666666666,13.166666666666666,13.45,13.45,13.45,13.45,13.45,13.45,13.45,13.45,13.45,13.45,13.45,13.45,13.45,13.45,13.45,13.45,13.45,13.45,13.45,13.45,13.45,13.45,13.45,13.45,13.45,22.15,22.15,23.65,23.65,23.65,23.65,23.65,25.016666666666666,25.016666666666666,25.016666666666666,28.516666666666666,28.516666666666666,28.516666666666666,24.316666666666666,24.316666666666666,26.316666666666666,26.316666666666666,26.316666666666666,26.316666666666666,26.316666666666666,35.666666666666664,35.666666666666664,25.15,25.15,25.15,25.15,26.3,26.3,38.93333333333333,38.93333333333333,38.93333333333333,38.93333333333333,38.93333333333333,38.93333333333333,10.1,10.1,12.383333333333333,12.383333333333333,12.383333333333333,12.383333333333333,12.383333333333333,12.383333333333333,11.6,11.6,11.6,11.6,11.6,12.966666666666667,12.966666666666667,12.966666666666667,16.466666666666665,16.466666666666665,16.466666666666665,23.616666666666667,23.616666666666667,13.1,13.1,13.1,13.1,14.25,14.25,29.516666666666666,26.883333333333333,26.883333333333333,26.883333333333333,26.883333333333333,26.883333333333333,26.883333333333333,28.433333333333334,28.433333333333334,24.016666666666666,24.016666666666666,24.016666666666666,24.016666666666666,24.016666666666666,24.016666666666666,24.016666666666666,24.016666666666666,24.016666666666666,24.016666666666666,18.366666666666667,19.433333333333334,19.433333333333334,19.433333333333334,19.433333333333334,19.433333333333334,19.433333333333334,19.433333333333334,19.433333333333334,19.433333333333334,19.433333333333334,30.733333333333334,30.733333333333334,30.733333333333334,30.733333333333334,30.733333333333334,30.733333333333334,30.733333333333334,30.733333333333334,45.38333333333333,45.38333333333333,45.38333333333333,45.38333333333333,45.38333333333333,13.75,13.75,13.75,13.75,24.583333333333332,24.583333333333332,24.583333333333332,24.583333333333332,14.35,14.35,14.35,14.35,19.583333333333 ...

# %%
df2 = pd.qcut(df.time, q = 3).value_counts()
df2
# Out:
# time
# (5.4159999999999995, 14.083]    158
# (19.483, 47.0]                  156
# (14.083, 19.483]                154
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#              time
# count  468.000000
# mean    18.727778
# std      7.313284
# min      5.416667
# 25%     13.729167
# 50%     16.183333
# 75%     23.154167
# max     47.000000

# %% [markdown]
# #### 마지막 도보시간 분포

# %%
import plotly.express as px
df = transit[transit.transit == 'WALK']
df.time = df.time / 60
fig = px.box(df,y="time", title = '마지막 도보시간  분포 (단위: 분)')
fig.update_yaxes(tickformat=',')

fig.show()
# Out:
# <ipython-input-155-5dc868cde8ef>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="47f0826e-7a88-4545-9b30-39e4bf93c487" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47f0826e-7a88-4545-9b30-39e4bf93c487")) {                    Plotly.newPlot(                        "47f0826e-7a88-4545-9b30-39e4bf93c487",                        [{"alignmentgroup":"True","hovertemplate":"time=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[5.05,4.233333333333333,4.15,5.05,4.233333333333333,4.15,5.05,4.233333333333333,4.15,5.05,1.9333333333333333,3.45,4.15,5.05,1.9333333333333333,3.45,4.15,5.05,1.9333333333333333,3.45,4.15,5.05,1.9333333333333333,2.35,4.15,5.05,1.9333333333333333,2.35,4.15,5.05,1.9333333333333333,2.35,4.15,5.05,1.9333333333333333,3.45,5.05,5.05,1.9333333333333333,3.45,5.05,5.05,1.9333333333333333,3.45,5.05,5.05,1.9333333333333333,3.45,5.05,5.05,1.9333333333333333,3.45,5.05,5.05,1.9333333333333333,3.45,5.05,5.05,1.9333333333333333,3.45,5.05,5.05,1.9333333333333333,3.45,5.05,5.05,1.9333333333333333,3.45,5.05,5.05,1.9333333333333333,3.45,5.05,5.05,1.9333333333333333,3.45,5.05,5.05,1.9333333333333333,3.45,5.05,5.05,3.5166666666666666,0.0,4.15,5.05,3.5166666666666666,0.0,4.15,5.05,3.5166666666666666,0.0,4.15,5.05,1.9333333333333333,1.9166666666666667,5.05,5.05,1.9333333333333333,1.9166666666666667,5.05,5.05,1.9333333333333333,1.9166666666666667,5.05,5.05,5.166666666666667,0.0,4.15,5.05,5.166666666666667,0.0,4.15,5.05,5.166666666666667,0.0,4.15,5.05,5.7,0.0,4.15,5.05,5.7,0.0,4.15,5.05,5.7,0.0,4.15,5.05,1.9333333333333333,2.533333333333333,4.15,5.05,1.9333333333333333,2.533333333333333,4.15,5.05,1.9333333333333333,2.533333333333333,4.15,5.05,1.9333333333333333,1.9166666666666667,0.0,4.15,5.05,1.9333333333333333,1.9166666666666667,0.0,4.15,5.05,1.9333333333333333,1.9166666666666667,0.0,4.15,5.05,1.9333333333333333,1.9166666666666667,0.0,4.15,5.05,1.9333333333333333,1.9166666666666667,0.0,4.15,5.05,1.9333333333333333,1.9166666666666667,0.0,4.15,5.05,1.9333333333333333,1.9166666666666667,0.0,4.15,5.05,1.9333333333333333,1.9166666666666667,0.0,4.15,5.05,1.9333333333333333,1.9166666666666667,0.0,4.15,8.916666666666666,3.283333333333333,4.7,3.4,10.066666666666666,8.916666666666666,3.283333333333333,4.766666666666667,8.6,8.916666666666666,3.283333333333333,4.7,2.6166666666666667,8.6,8.916666666666666,3.283333333333333,6.516666666666667,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,0.0,8.6,5.05,2.783333333333333,5.1,10.066666666666666,5.05,2.783333333333333,5.1,10.066666666666666,5.05,2.783333333333333,5.1,10.066666666666666,5.05,2.783333333333333,5.1,10.066666666666666,5.05,2.783333333333333,5.1,10.0666666666 ...

# %%
df2 = pd.qcut(df.time, q = 3).value_counts()
df2
# Out:
# time
# (-0.001, 2.333]    726
# (2.333, 4.55]      660
# (4.55, 31.0]       640
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#          transitID         time
# count  2026.000000  2026.000000
# mean      4.570582     4.326061
# std       2.860925     4.300948
# min       1.000000     0.000000
# 25%       3.000000     1.933333
# 50%       5.000000     3.733333
# 75%       7.000000     5.050000
# max      13.000000    31.000000

# %% [markdown]
# #### 축제별 도보시간 합계 분포

# %%
df = transit[transit.transit == 'WALK'].groupby(['dest_cd', 'routeID']).time.sum().reset_index()
df.time = df.time/60
fig = px.box(df,x = 'dest_cd', y = "time", title = '축제별 도보시간 합계 분포 (단위: 분)')
fig.update_yaxes(tickformat=',')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fef74c3e-9ad1-4c72-a26d-cc6b2b0a31ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fef74c3e-9ad1-4c72-a26d-cc6b2b0a31ed")) {                    Plotly.newPlot(                        "fef74c3e-9ad1-4c72-a26d-cc6b2b0a31ed",                        [{"alignmentgroup":"True","hovertemplate":"dest_cd=%{x}\u003cbr\u003etime=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac1 ...

# %%
df2 = pd.qcut(df.time, q = 3).value_counts()
df2
# Out:
# time
# (5.4159999999999995, 14.083]    158
# (19.483, 47.0]                  156
# (14.083, 19.483]                154
# Name: count, dtype: int64

# %%
df[df.dest_cd == '강릉(경포호수광장)'].describe()
# Out:
#             time
# count  80.000000
# mean   18.214792
# std     6.543904
# min    10.100000
# 25%    13.100000
# 50%    14.041667
# 75%    26.883333
# max    29.516667

# %%
df[df.dest_cd == '강릉(스피드 스케이트 경기장)'].describe()
# Out:
#             time
# count  47.000000
# mean   29.843262
# std     7.731326
# min    18.133333
# 25%    24.316667
# 50%    26.316667
# 75%    37.000000
# max    47.000000

# %%
df[df.dest_cd == '대전'].describe()
# Out:
#              time
# count  135.000000
# mean    13.892346
# std      1.059549
# min      8.000000
# 25%     13.441667
# 50%     13.666667
# 75%     14.491667
# max     18.100000

# %%
df[df.dest_cd == '부산'].describe()
# Out:
#             time
# count  61.000000
# mean   17.570765
# std     3.983032
# min    11.216667
# 25%    16.433333
# 50%    16.433333
# 75%    16.433333
# max    30.366667

# %%
df[df.dest_cd == '서울'].describe()
# Out:
#             time
# count  88.000000
# mean   16.332955
# std     4.730708
# min     5.416667
# 25%    13.750000
# 50%    16.183333
# 75%    21.733333
# max    24.583333

# %%
df[df.dest_cd == '임실'].describe()
# Out:
#             time
# count  57.000000
# mean   26.670175
# std     6.851218
# min    18.366667
# 25%    24.016667
# 50%    26.116667
# 75%    28.433333
# max    45.383333

# %% [markdown]
# #### 축제별 마지막 도보시간 분포

# %%
df = transit[transit.transit == 'WALK'].drop_duplicates(subset = 'routeID', keep = 'last')
df.time = df.time / 60
fig = px.box(df, x = 'dest_cd', y = 'time', title = '축제별 마지막 도보시간 분포(단위: 분)')
fig.update_yaxes(tickformat = ',')
fig.update_layout(
    xaxis_title="도착지", yaxis_title="도보시간"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a94dd140-b667-47d8-99da-8fb195b053d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a94dd140-b667-47d8-99da-8fb195b053d6")) {                    Plotly.newPlot(                        "a94dd140-b667-47d8-99da-8fb195b053d6",                        [{"alignmentgroup":"True","hovertemplate":"dest_cd=%{x}\u003cbr\u003etime=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ub300\uc804","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\ubd80\uc0b0","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)" ...

# %%
df[df.dest_cd == '대전'].describe()
# Out:
#         transitID        time
# count  135.000000  135.000000
# mean     7.325926    4.556667
# std      1.177080    0.449577
# min      1.000000    4.150000
# 25%      7.000000    4.150000
# 50%      7.000000    4.150000
# 75%      7.000000    5.050000
# max      9.000000    5.050000

# %%
df[df.dest_cd == '부산'].describe()
# Out:
#        transitID       time
# count  61.000000  61.000000
# mean    6.573770   8.864481
# std     1.161307   0.628457
# min     3.000000   7.133333
# 25%     7.000000   8.600000
# 50%     7.000000   8.600000
# 75%     7.000000   8.600000
# max     9.000000  10.066667

# %%
df[df.dest_cd == '강릉(스피드 스케이트 경기장)'].describe()
# Out:
#        transitID       time
# count  47.000000  47.000000
# mean    8.212766  19.442553
# std     1.887443   5.450000
# min     4.000000  14.000000
# 25%     6.000000  17.250000
# 50%     9.000000  17.250000
# 75%     9.000000  17.250000
# max    11.000000  31.000000

# %%
df[df.dest_cd == '강릉(경포호수광장)'].describe()
# Out:
#        transitID       time
# count  80.000000  80.000000
# mean    9.525000   4.878958
# std     2.375908   0.508588
# min     5.000000   4.083333
# 25%     7.000000   4.083333
# 50%     9.000000   5.200000
# 75%    11.000000   5.200000
# max    13.000000   5.200000

# %%
df[df.dest_cd == '임실'].describe()
# Out:
#        transitID       time
# count  57.000000  57.000000
# mean    8.473684  16.144737
# std     2.659923   6.855225
# min     5.000000   7.883333
# 25%     5.000000   7.883333
# 50%     9.000000  21.733333
# 75%    11.000000  21.733333
# max    11.000000  21.733333

# %%
df[df.dest_cd == '서울'].describe()
# Out:
#        transitID       time
# count  88.000000  88.000000
# mean    6.250000   3.987879
# std     1.019917   0.948800
# min     3.000000   3.216667
# 25%     5.000000   3.216667
# 50%     7.000000   3.433333
# 75%     7.000000   5.150000
# max     7.000000   5.466667

# %% [markdown]
# #### 평균 환승 횟수

# %%
df = transit[(transit.transitID != 99)].groupby('dest_cd').transitID.mean().reset_index()
layout = go.Layout(title = '<b> 평균 환승 횟수 <b>'
                  , xaxis_title = '목적지'
                  , yaxis_title = '환승 수'
                  , font_size = 14)
fig = go.Figure(data = go.Bar(x = df.dest_cd, y = df.transitID, width = 0.3, marker_color = '#80b0d3'), layout = layout)

fig.update_yaxes(tickformat=',')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6fd6491c-9d60-44b8-bfc6-62fbe769d7e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6fd6491c-9d60-44b8-bfc6-62fbe769d7e5")) {                    Plotly.newPlot(                        "6fd6491c-9d60-44b8-bfc6-62fbe769d7e5",                        [{"marker":{"color":"#80b0d3"},"width":0.3,"x":["\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\ub300\uc804","\ubd80\uc0b0","\uc11c\uc6b8","\uc784\uc2e4"],"y":[5.579354838709677,4.818652849740933,4.266800401203611,3.887780548628429,3.707272727272727,5.146997929606625],"type":"bar"}],                        {"font":{"size":14},"title":{"text":"\u003cb\u003e \ud3c9\uade0 \ud658\uc2b9 \ud69f\uc218 \u003cb\u003e"},"xaxis":{"title":{"text":"\ubaa9\uc801\uc9c0"}},"yaxis":{"title":{"text":"\ud658\uc2b9 \uc218"},"tickformat":","},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2 ...

# %%
df.describe()
# Out:
#        transitID
# count   6.000000
# mean    4.567810
# std     0.736909
# min     3.707273
# 25%     3.982536
# 50%     4.542727
# 75%     5.064912
# max     5.579355

# %%
df2 = pd.qcut(df.transitID, q = 3).value_counts()
df2
# Out:
# transitID
# (3.706, 4.14]     2
# (4.14, 4.928]     2
# (4.928, 5.579]    2
# Name: count, dtype: int64

# %% [markdown]
# ### 교통수단 접근성 관련

# %% [markdown]
# #### 대중교통 경로 비교

# %%
df = transit.groupby(['origin_cd', 'dest_cd']).routeID.nunique().reset_index()

df_S = df[df.origin_cd == '서울']
df_B = df[df.origin_cd == '부산']

data_S = go.Bar(x = df_S.dest_cd, y = df_S.routeID, name = '서울', width = 0.4, marker_color = '#80b0d3')
data_B = go.Bar(x = df_B.dest_cd, y = df_B.routeID, name = '부산', width = 0.4, marker_color = '#fb8072')

layout = go.Layout(title = '대중교통 경로 수 비교'
                  , xaxis_title = '축제'
                  , yaxis_title = '경로')

fig = go.Figure(data = [data_S, data_B], layout = layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="240e3d51-ceb5-49aa-9566-825c48a49933" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("240e3d51-ceb5-49aa-9566-825c48a49933")) {                    Plotly.newPlot(                        "240e3d51-ceb5-49aa-9566-825c48a49933",                        [{"marker":{"color":"#80b0d3"},"name":"\uc11c\uc6b8","width":0.4,"x":["\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\ub300\uc804","\ubd80\uc0b0","\uc11c\uc6b8","\uc784\uc2e4"],"y":[46,13,45,46,20,21],"type":"bar"},{"marker":{"color":"#fb8072"},"name":"\ubd80\uc0b0","width":0.4,"x":["\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\ub300\uc804","\ubd80\uc0b0","\uc11c\uc6b8","\uc784\uc2e4"],"y":[34,34,90,15,68,36],"type":"bar"}],                        {"title":{"text":"\ub300\uc911\uad50\ud1b5 \uacbd\ub85c \uc218 \ube44\uad50"},"xaxis":{"title":{"text":"\ucd95\uc81c"}},"yaxis":{"title":{"text":"\uacbd\ub85c"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth": ...

# %% [markdown]
# #### 대중교통 수

# %%
df = transit[(transit.transitID != 99)&(transit.transit != 'WALK')].groupby(['dest_cd']).transit.nunique().reset_index()

layout = go.Layout(title = '<b> 이용 가능 대중교통 <b>'
                  , xaxis_title = '목적지'
                  , yaxis_title = '대중교통 수'
                  , font_size = 14)
fig = go.Figure(data = go.Bar(x = df.dest_cd, y = df.transit, width = 0.3, marker_color = '#80b0d3'), layout = layout)

fig.update_yaxes(tickformat=',')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="22a111e4-d99e-4834-ab16-155a4dd23d4d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("22a111e4-d99e-4834-ab16-155a4dd23d4d")) {                    Plotly.newPlot(                        "22a111e4-d99e-4834-ab16-155a4dd23d4d",                        [{"marker":{"color":"#80b0d3"},"width":0.3,"x":["\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\ub300\uc804","\ubd80\uc0b0","\uc11c\uc6b8","\uc784\uc2e4"],"y":[4,4,3,4,3,4],"type":"bar"}],                        {"font":{"size":14},"title":{"text":"\u003cb\u003e \uc774\uc6a9 \uac00\ub2a5 \ub300\uc911\uad50\ud1b5 \u003cb\u003e"},"xaxis":{"title":{"text":"\ubaa9\uc801\uc9c0"}},"yaxis":{"title":{"text":"\ub300\uc911\uad50\ud1b5 \uc218"},"tickformat":","},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fil ...

# %%
df
# Out:
#             dest_cd  transit
# 0        강릉(경포호수광장)        4
# 1  강릉(스피드 스케이트 경기장)        4
# 2                대전        3
# 3                부산        4
# 4                서울        3
# 5                임실        4

# %%
df = transit[(transit.transitID != 99)&(transit.transit != 'WALK')].groupby(['dest_cd']).transit.value_counts().reset_index()
df
# Out:
#              dest_cd     transit  count
# 0         강릉(경포호수광장)         BUS    220
# 1         강릉(경포호수광장)  EXPRESSBUS     58
# 2         강릉(경포호수광장)      SUBWAY     46
# 3         강릉(경포호수광장)       TRAIN     23
# 4   강릉(스피드 스케이트 경기장)         BUS     91
# 5   강릉(스피드 스케이트 경기장)      SUBWAY     35
# 6   강릉(스피드 스케이트 경기장)  EXPRESSBUS     34
# 7   강릉(스피드 스케이트 경기장)       TRAIN     14
# 8                 대전         BUS    198
# 9                 대전       TRAIN    135
# 10                대전      SUBWAY     98
# 11                부산         BUS     92
# 12                부산       TRAIN     46
# 13                부산      SUBWAY     28
# 14                부산    AIRPLANE      4
# 15                서울         BUS     91
# 16                서울      SUBWAY     72
# 17                서울       TRAIN     68
# 18                임실       TRAIN     70
# 19                임실         BUS     56
# 20                임실  EXPRESSBUS     51
# 21                임실      SUBWAY     36

# %% [markdown]
# ### 거리 접근성 관련

# %%
df = transit[(transit.transitID == 99)&((transit.transit == 'totalDistance'))]
df.time.describe()
fig = px.box(df,y="time", title = '(전체) 이동거리 분포')
fig.update_yaxes(tickformat=',')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="51eaa9f6-eb0d-4fc3-8093-98e36b74cfba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51eaa9f6-eb0d-4fc3-8093-98e36b74cfba")) {                    Plotly.newPlot(                        "51eaa9f6-eb0d-4fc3-8093-98e36b74cfba",                        [{"alignmentgroup":"True","hovertemplate":"time=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[151529.0,151529.0,151529.0,152096.0,152096.0,152096.0,152651.0,152651.0,152651.0,152406.0,152406.0,152406.0,152406.0,152406.0,152406.0,152406.0,152406.0,152406.0,152406.0,152406.0,152406.0,150675.0,150675.0,150675.0,153045.0,153045.0,153045.0,151034.0,151034.0,151034.0,151543.0,151543.0,151543.0,154480.0,154480.0,154480.0,152219.0,152219.0,152219.0,152219.0,152219.0,152219.0,152219.0,152219.0,152219.0,367314.0,369479.0,369450.0,369221.0,340827.0,340827.0,340827.0,340827.0,340827.0,340827.0,340827.0,340827.0,340827.0,340827.0,340827.0,340827.0,340838.0,340838.0,340838.0,340838.0,340838.0,340838.0,340860.0,340860.0,340860.0,340860.0,340860.0,340860.0,340860.0,340860.0,340860.0,340841.0,340841.0,340841.0,340841.0,340841.0,340841.0,341077.0,341077.0,341077.0,341077.0,341077.0,341077.0,341077.0,341077.0,341077.0,191607.0,198254.0,195186.0,220586.0,218288.0,218288.0,218288.0,218288.0,218288.0,191468.0,null,null,194126.0,177862.0,177862.0,178149.0,182214.0,182214.0,182214.0,182214.0,182214.0,182214.0,182214.0,182214.0,182214.0,182214.0,182214.0,182214.0,182214.0,182214.0,182214.0,182214.0,182214.0,182214.0,182214.0,182214.0,195422.0,195422.0,195422.0,195422.0,206356.0,206356.0,206356.0,206356.0,206356.0,206356.0,206356.0,206356.0,206356.0,206356.0,206356.0,206356.0,206356.0,206356.0,206356.0,206356.0,206356.0,206356.0,206356.0,206356.0,217913.0,217913.0,226523.0,226523.0,226523.0,226523.0,226523.0,226523.0,226523.0,226523.0,218379.0,218379.0,216592.0,216592.0,216432.0,216432.0,221938.0,221938.0,220029.0,226695.0,226695.0,6846.0,6846.0,6846.0,6846.0,6724.0,6202.0,6202.0,9251.0,9251.0,10328.0,10328.0,8809.0,8809.0,9549.0,9549.0,10875.0,10875.0,6775.0,6775.0,6769.0,208132.0,208132.0,208132.0,208132.0,208132.0,208699.0,208699.0,208699.0,208699.0,208699.0,208699.0,208699.0,208699.0,208699.0,208699.0,209254.0,209254.0,209254.0,209254.0,209254.0,209009.0,209009.0,209009.0,209009.0,209009.0,209009.0,209009.0,209009.0,209009.0,209009.0,209009.0,209009.0,209009.0,209009.0,209009.0,207278.0,207278.0,207278.0,207278.0,207278.0,209648.0,209648.0,209648.0,209648.0,209648.0,207637.0,207637.0,207637.0,207637.0,207637.0,208146.0,208146.0,208146.0,208146.0,208146.0,208146.0,208146.0,208146.0,208146.0,208146.0,211083.0,211083.0,211083.0,211083.0,211083.0,209114.0,209114.0,209114.0,209114.0,209114.0,209114.0,209114.0,209114.0,209114.0,209114.0,209114.0,209114.0,209114.0,209114.0,209114.0,209114.0,209114.0,209114.0,209114.0,209114.0,209114.0,209114.0,209114.0,209114.0,209114.0,13077.0,14700.0,14700.0,16696.0,13452.0,13452.0,13452.0,17256.0,13040.0,13699.0,15284.0,25962.0,25962.0,25962.0,25962.0,300502.0,300502.0,303565.0,303565.0,303565.0,303565.0,303565.0,304213.0,304213.0,304213.0,303622.0,303622.0,303622.0,305638.0,305638.0,305556.0,305556.0,305556.0,305556.0,305556.0,300684.0,300684.0,308271.0,308271.0,308271.0,308271.0,308473.0,308473.0,299594.0,299594.0,299594.0,299594.0,299594.0,299594.0,304010.0,304010.0,303365.0,303365.0,303365.0,303365.0,303365.0,303365.0,307073.0,307073.0,307073.0,307073.0,307073.0,307721.0,307721.0,307721.0,307130.0,307130.0,307130.0,30419.0,30419.0,311778.0,311778.0,311778.0,311778.0,311981.0,311981.0,304159.0,303102.0,303102.0,303 ...

# %%
df.time.describe()
# Out:
# count       467.000000
# mean     233046.691649
# std       92572.788266
# min        6202.000000
# 25%      196838.000000
# 50%      217913.000000
# 75%      308473.000000
# max      369479.000000
# Name: time, dtype: float64

# %%
df2 = pd.qcut(df.time, q = 3).value_counts()
df2
# Out:
# time
# (6201.999, 208146.0]    163
# (303365.0, 369479.0]    154
# (208146.0, 303365.0]    150
# Name: count, dtype: int64

# %%
df = transit[(transit.transitID == 99)&((transit.transit == 'totalDistance'))].groupby(['origin_cd', 'dest_cd']).time.mean().reset_index()

df = df.groupby(['origin_cd', 'dest_cd']).time.mean().reset_index()
df.time = round(df.time) / 1000
df_S = df[df.origin_cd == '서울']
df_B = df[df.origin_cd == '부산']

data_S = go.Bar(x = df_S.time, y = df_S.dest_cd, name = '서울', width = 0.3, orientation='h', marker_color = '#80b0d3')
data_B = go.Bar(x = df_B.time, y = df_B.dest_cd, name = '부산', width = 0.3, orientation='h', marker_color = '#fb8072')

layout = go.Layout(title = '<b> 평균 이동거리 비교 <b>'
                  , xaxis_title = '이동거리(단위: km)'
                  , yaxis_title = '목적지'
                  , font_size = 14)

fig = go.Figure(data = [data_S, data_B], layout = layout)
fig.update_yaxes(tickformat=',')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7308667c-5841-4104-b7bb-c53e75914531" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7308667c-5841-4104-b7bb-c53e75914531")) {                    Plotly.newPlot(                        "7308667c-5841-4104-b7bb-c53e75914531",                        [{"marker":{"color":"#80b0d3"},"name":"\uc11c\uc6b8","orientation":"h","width":0.3,"x":[193.34,207.515,152.222,343.324,8.223,222.291],"y":["\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\ub300\uc804","\ubd80\uc0b0","\uc11c\uc6b8","\uc784\uc2e4"],"type":"bar"},{"marker":{"color":"#fb8072"},"name":"\ubd80\uc0b0","orientation":"h","width":0.3,"x":[290.083,303.834,208.851,17.51,318.53,252.09],"y":["\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\ub300\uc804","\ubd80\uc0b0","\uc11c\uc6b8","\uc784\uc2e4"],"type":"bar"}],                        {"font":{"size":14},"title":{"text":"\u003cb\u003e \ud3c9\uade0 \uc774\ub3d9\uac70\ub9ac \ube44\uad50 \u003cb\u003e"},"xaxis":{"title":{"text":"\uc774\ub3d9\uac70\ub9ac(\ub2e8\uc704: km)"}},"yaxis":{"title":{"text":"\ubaa9\uc801\uc9c0"},"tickformat":","},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewi ...

# %% [markdown]
# ### 시간 접근성 관련

# %% [markdown]
# #### 소요시간 분포

# %%
import plotly.express as px
df = transit[transit.transitID != 99].groupby('routeID').time.sum().reset_index()
df.time = df.time / 60
fig = px.box(df,y="time", title = '이동시간 합계 분포 (단위: 분)')
fig.update_yaxes(tickformat=',')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="04f6535d-a528-4ab3-bc8b-de3a45153458" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04f6535d-a528-4ab3-bc8b-de3a45153458")) {                    Plotly.newPlot(                        "04f6535d-a528-4ab3-bc8b-de3a45153458",                        [{"alignmentgroup":"True","hovertemplate":"time=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[56.15,47.35,47.35,49.71666666666667,48.9,48.9,48.9,68.16666666666667,51.28333333333333,51.1,45.96666666666667,78.31666666666666,90.21666666666667,78.31666666666666,74.11666666666666,142.75,132.75,142.75,239.66666666666666,210.58333333333334,123.95,123.95,133.95,133.95,230.86666666666667,230.86666666666667,201.78333333333333,201.78333333333333,133.95,133.95,126.95,136.95,233.86666666666667,204.78333333333333,136.95,125.5,125.5,125.5,135.5,135.5,135.5,232.41666666666666,232.41666666666666,232.41666666666666,203.33333333333334,203.33333333333334,203.33333333333334,135.5,135.5,135.5,131.1,141.1,238.01666666666668,208.93333333333334,141.1,132.13333333333333,142.13333333333333,239.05,209.96666666666667,142.13333333333333,133.51666666666668,143.51666666666668,240.43333333333334,211.35,143.51666666666668,134.06666666666666,134.06666666666666,144.06666666666666,144.06666666666666,240.98333333333332,240.98333333333332,211.9,211.9,144.06666666666666,144.06666666666666,136.1,146.1,243.01666666666668,213.93333333333334,146.1,127.25,127.25,127.25,127.25,127.25,137.25,137.25,137.25,137.25,137.25,234.16666666666666,234.16666666666666,234.16666666666666,234.16666666666666,234.16666666666666,205.08333333333334,205.08333333333334,205.08333333333334,205.08333333333334,205.08333333333334,137.25,137.25,137.25,137.25,137.25,368.46666666666664,368.46666666666664,380.46666666666664,380.46666666666664,380.46666666666664,380.46666666666664,380.46666666666664,383.51666666666665,383.51666666666665,383.51666666666665,384.26666666666665,384.26666666666665,384.26666666666665,387.43333333333334,387.43333333333334,389.6333333333333,389.6333333333333,389.6333333333333,389.6333333333333,389.6333333333333,378.15,378.15,398.85,398.85,398.85,398.85,401.18333333333334,401.18333333333334,376.18333333333334,376.18333333333334,376.18333333333334,376.18333333333334,376.18333333333334,376.18333333333334,367.46666666666664,367.46666666666664,368.21666666666664,368.21666666666664,368.21666666666664,368.21666666666664,368.21666666666664,368.21666666666664,379.46666666666664,379.46666666666664,379.46666666666664,379.46666666666664,379.46666666666664,382.51666666666665,382.51666666666665,382.51666666666665,383.26666666666665,383.26666666666665,383.26666666666665,377.15,377.15,397.85,397.85,397.85,397.85,400.18333333333334,400.18333333333334,383.01666666666665,375.18333333333334,375.18333333333334,375.18333333333334,375.18333333333334,375.18333333333334,375.18333333333334,295.8833333333333,286.5,270.48333333333335,270.48333333333335,331.93333333333334,331.93333333333334,316.48333333333335,316.48333333333335,280.48333333333335,280.48333333333335,280.48333333333335,280.48333333333335,319.65,315.6666666666667,315.6666666666667,315.6666666666667,315.6666666666667,315.6666666666667,315.6666666666667,315.6666666666667,315.6666666666667,315.6666666666667,315.6666666666667,320.3833333333333,333.4,320.3833333333333,333.4,320.3833333333333,333.4,320.3833333333333,333.4,298.43333333333334,359.8833333333333,344.43333333333334,308.43333333333334,308.43333333333334,207.86666666666667,377.6,326.6666666666667,207.86666666666667,201.88333333333333,371.6166666666667,320.68333333333334,201.883333333333 ...

# %%
df.describe()
# Out:
#              time
# count  468.000000
# mean   239.110399
# std    106.775193
# min     25.700000
# 25%    158.500000
# 50%    216.575000
# 75%    338.133333
# max    565.600000

# %%
df[df.time == 4.3]
# Out:
# Empty DataFrame
# Columns: [routeID, time]
# Index: []

# %%
transit[transit.routeID == 'BI33']
# Out:
# Empty DataFrame
# Columns: [routeID, transitID, transit, description, time, origin_cd, dest_cd]
# Index: []

# %% [markdown]
# #### 평균 소요시간 비교

# %%
df = transit[(transit.transitID == 99) & (transit.transit == 'totalTime')]
df = df.groupby(['origin_cd', 'dest_cd']).time.mean().reset_index()
df.time = round(df.time) /60
df_S = df[df.origin_cd == '서울']
df_B = df[df.origin_cd == '부산']

data_S = go.Bar(x = df_S.time, y = df_S.dest_cd, name = '서울', width = 0.3, orientation='h', marker_color = '#80b0d3')
data_B = go.Bar(x = df_B.time, y = df_B.dest_cd, name = '부산', width = 0.3, orientation='h', marker_color = '#fb8072')

layout = go.Layout(title = '<b> 평균 소요시간 비교 (단위: 분) <b>'
                  , xaxis_title = '소요시간(단위: 분)'
                  , yaxis_title = '목적지'
                  , font_size = 14)

fig = go.Figure(data = [data_S, data_B], layout = layout)
fig.update_yaxes(tickformat=',')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="36f3288b-c1aa-4fab-824b-c712aa8f8779" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36f3288b-c1aa-4fab-824b-c712aa8f8779")) {                    Plotly.newPlot(                        "36f3288b-c1aa-4fab-824b-c712aa8f8779",                        [{"marker":{"color":"#80b0d3"},"name":"\uc11c\uc6b8","orientation":"h","width":0.3,"x":[225.81666666666666,426.81666666666666,152.43333333333334,305.73333333333335,30.85,220.71666666666667],"y":["\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\ub300\uc804","\ubd80\uc0b0","\uc11c\uc6b8","\uc784\uc2e4"],"type":"bar"},{"marker":{"color":"#fb8072"},"name":"\ubd80\uc0b0","orientation":"h","width":0.3,"x":[262.28333333333336,315.1,169.91666666666666,58.983333333333334,279.85,312.5833333333333],"y":["\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\ub300\uc804","\ubd80\uc0b0","\uc11c\uc6b8","\uc784\uc2e4"],"type":"bar"}],                        {"font":{"size":14},"title":{"text":"\u003cb\u003e \ud3c9\uade0 \uc18c\uc694\uc2dc\uac04 \ube44\uad50 (\ub2e8\uc704: \ubd84) \u003cb\u003e"},"xaxis":{"title":{"text":"\uc18c\uc694\uc2dc\uac04(\ub2e8\uc704: \ubd84)"}},"yaxis":{"title":{"text":"\ubaa9\uc801\uc9c0"},"tickformat":","},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0. ...

# %% [markdown]
# #### 축제별 이동시간

# %%
df = transit[transit.transitID != '99'].groupby(['dest_cd','origin_cd','routeID']).time.sum().reset_index()
df.time = df.time / 60

fig = px.box(df,x = 'dest_cd', y = "time",color = 'origin_cd', title = '축제별 이동시간 합계 분포 (단위: 분)')
fig.update_yaxes(tickformat=',')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="34aa4500-16fb-4896-a0b1-c47c8c6b6726" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("34aa4500-16fb-4896-a0b1-c47c8c6b6726")) {                    Plotly.newPlot(                        "34aa4500-16fb-4896-a0b1-c47c8c6b6726",                        [{"alignmentgroup":"True","hovertemplate":"origin_cd=\ubd80\uc0b0\u003cbr\u003edest_cd=%{x}\u003cbr\u003etime=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\ubd80\uc0b0","marker":{"color":"#636efa"},"name":"\ubd80\uc0b0","notched":false,"offsetgroup":"\ubd80\uc0b0","orientation":"v","showlegend":true,"x":["\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uacbd\ud3ec\ud638\uc218\uad11\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc774\ud2b8 \uacbd\uae30\uc7a5)","\uac15\ub989(\uc2a4\ud53c\ub4dc \uc2a4\ucf00\uc7 ...

# %% [markdown]
# #### 이동수단별 이동시간

# %%
df = transit[transit.transitID != 99].groupby(['origin_cd','transit', 'routeID']).time.sum().reset_index()
fig = px.box(df, x = 'transit', y = 'time', color = 'origin_cd', title = '이동수단별 평균 이동시간')
fig.update_yaxes(tickformat = ',')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="088d4f42-a36f-4f4a-8c0e-b87ca91d6965" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("088d4f42-a36f-4f4a-8c0e-b87ca91d6965")) {                    Plotly.newPlot(                        "088d4f42-a36f-4f4a-8c0e-b87ca91d6965",                        [{"alignmentgroup":"True","hovertemplate":"origin_cd=\ubd80\uc0b0\u003cbr\u003etransit=%{x}\u003cbr\u003etime=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\ubd80\uc0b0","marker":{"color":"#636efa"},"name":"\ubd80\uc0b0","notched":false,"offsetgroup":"\ubd80\uc0b0","orientation":"v","showlegend":true,"x":["BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","BUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","EXPRESSBUS","SUBWAY","SUBWAY","SUBWAY","SUBWAY","SUBWAY","SUBWAY","SUBWAY","SUBWAY","SUBWAY","SUBWAY","SUBWAY","SUBWAY","SUBWAY","SUBWAY","SUBWAY","SUBWAY","SUBWAY","SUBWAY","SUBWAY","SUBWAY","SUBWAY","SUBWAY","SUBWAY","SUBWAY","SUBWAY","SUB ...
